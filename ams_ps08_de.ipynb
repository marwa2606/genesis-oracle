# %% [markdown]
# <a href="https://colab.research.google.com/github/marwa2606/genesis-oracle/blob/main/ams_ps08_de.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem Set 8: Project Genesis – Der souveräne Wächter
#
# Sensible Telemetriedaten, physikalische Anomalien und geschützte Systemzustände wurden über unsichere Netzwerke an externe Server übertragen. Jede Millisekunde Latenz bedrohte die Stabilität eurer Echtzeitschleifen; jeder Netzwerkausfall führte zum sofortigen Zusammenbruch eures digitalen Abbilds.
#
# Heute errichten wir die **Festung der Autarkie**. Ihr werdet ein hochentwickeltes, lokal lauffähiges Modell der **Google Gemma 4**-Familie tief im Fundament eurer eigenen Hardware verankern. Eure Mission ist es, eine ereignisdiskrete Warteschlangensimulation – das pulsierende Herz einer virtuellen Fabrikationsstraße – mit diesem lokalen Wächter zu koppeln. Ohne ein einziges Datenpaket nach außen zu senden, wird der Wächter die Telemetrie überwachen, im geschützten Denkanal logische Analysen durchführen, auf eine lokale Wissensdatenbank zugreifen und regulierend in die Physik der Warteschlange eingreifen.
#
# Bereitet eure Terminals vor. Aktiviert die lokalen Tensor-Kerne. Die Souveränität über die Daten ist der Schlüssel zur absoluten Kontrolle. Let's build!

# %% [markdown]
# ## Exercise 1: Die Initialisierung des lokalen Wächters (Gemma 4 Edge)
#
# Wir verwenden die hochgradig effiziente Variante **Gemma 4 E2B-IT**. Dieses Modell weist trotz seiner kompakten Größe (2,3 Milliarden effektive Parameter) dank der neuartigen Per-Layer Embeddings (PLE) eine exzellente Logikfähigkeit auf.
#
# ### Instruktionen:
# 1. Melden Sie sich bei [Kaggle](https://www.kaggle.com) an und akzeptieren Sie die Nutzungsbedingungen auf der offiziellen Gemma 4 Modellseite.
# 2. Erstellen Sie ein API-Token in Ihren Kaggle-Kontoeinstellungen, um die Datei `kaggle.json` herunterzuladen.
# 3. Setzen Sie die Umgebungsvariablen `KAGGLE_USERNAME` und `KAGGLE_KEY` in Ihrer Python-Laufzeitumgebung.
# 4. Laden Sie das Modell mit `kagglehub` herunter und initialisieren Sie die Inferenz-Pipeline.

# %%
import os
import kagglehub

# Tragen Sie hier Ihre Credentials ein (oder nutzen Sie eine .env Datei)
os.environ["KAGGLE_USERNAME"] = "marwaalmousli"
os.environ["KAGGLE_KEY"] = "KGAT_74a414ac90de98a4bac8e93bd3de951f"

try:
    print("Fordere Gewichte von der Kaggle-Schnittstelle an...")
    # Herunterladen der instruction-tuned Gemma 4 E2B Variante über kagglehub
    model_path = kagglehub.model_download("google/gemma-4/transformers/gemma-4-e2b-it")
    print(f"Modell erfolgreich lokalisiert im Systemcache unter: {model_path}")
except Exception as e:
    print(f"Fehler beim Herunterladen des Modells: {e}")
    print("Sicherstellen, dass die Modell-Lizenz auf Kaggle akzeptiert wurde und die API-Schlüssel korrekt konfiguriert sind.")
# Out:
# Fordere Gewichte von der Kaggle-Schnittstelle an...
# Downloading 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# Downloading to /root/.cache/kagglehub/models/google/gemma-4/transformers/gemma-4-e2b-it/1/tokenizer_config.json...
# Downloading to /root/.cache/kagglehub/models/google/gemma-4/transformers/gemma-4-e2b-it/1/generation_config.json...
# Downloading to /root/.cache/kagglehub/models/google/gemma-4/transformers/gemma-4-e2b-it/1/config.json...
#   0%|          | 0.00/2.02k [00:00<?, ?B/s]
#
#   0%|          | 0.00/208 [00:00<?, ?B/s]
#
#
# 100%|██████████| 2.02k/2.02k [00:00<00:00, 332kB/s]
# 100%|██████████| 208/208 [00:00<00:00, 39.5kB/s]
# 100%|██████████| 4.84k/4.84k [00:00<00:00, 1.55MB/s]
# Downloading to /root/.cache/kagglehub/models/google/gemma-4/transformers/gemma-4-e2b-it/1/chat_template.jinja...
# 100%|██████████| 11.6k/11.6k [00:00<00:00, 26.0MB/s]
# Downloading to /root/.cache/kagglehub/models/google/gemma-4/transformers/gemma-4-e2b-it/1/processor_config.json...
# 100%|██████████| 1.65k/1.65k [00:00<00:00, 2.39MB/s]
# Downloading to /root/.cache/kagglehub/models/google/gemma-4/transformers/gemma-4-e2b-it/1/README.md...
# 100%|██████████| 21.3k/21.3k [00:00<00:00, 18.2MB/s]
# Downloading to /root/.cache/kagglehub/models/google/gemma-4/transformers/gemma-4-e2b-it/1/model.safetensors...
#   0%|          | 0.00/9.54G [00:00<?, ?B/s]
#   0%|          | 1.00M/9.54G [00:01<3:40:17, 775kB/s]
#   0%|          | 2.00M/9.54G [00:01<1:53:18, 1.51MB/s]
#   0%|          | 3.00M/9.54G [00:01<1:11:34, 2.39MB/s]
#   0%|          | 5.00M/9.54G [00:01<38:53, 4.39MB/s]
#   0%|          | 7.00M/9.54G [00:02<25:24, 6.71MB/s]
#   0%|          | 9.00M/9.54G [00:02<19:31, 8.74MB/s]
#   0%|          | 11.0M/9.54G [00:02<15:30, 11.0MB/s]
#   0%|          | 13.0M/9.54G [00:02<13:59, 12.2MB/s]
#   0%|          | 15.0M/9.54G [00:02<12:20, 13.8MB/s]
#   0%|          | 17.0M/9.54G [00:02<11:26, 14.9MB/s]
#   0%|          | 19.0M/9.54G [00:02<10:36, 16.1MB/s]
# Downloading to /root/.cache/kagglehub/models/google/gemma-4/transformers/gemma-4-e2b-it/1/tokenizer.json...
#   0%|          | 0.00/30.7M [00:00<?, ?B/s]
#   0%|          | 21.0M/9.54G [00:03<32:45, 5.20MB/s]
#
# 100%|██████████| 30.7M/30.7M [00:00<00:00, 232MB/s]
#
#   0%|          | 27.0M/9.54G [00:03<17:33, 9.70MB/s]
#   0%|          | 31.0M/9.54G [00:04<14:35, 11.7MB/s]
#   0%|          | 34.0M/9.54G [00:04<13:39, 12.5MB/s]
#   0%|          | 38.0M/9.54G [00:04<12:05, 14.1MB/s]
#   0%|          | 41.0M/9.54G [00:04<11:44, 14.5MB/s]
#   0%|          | 45.0M/9.54G [00:05<10:49, 15.7MB/s]
#   1%|          | 49.0M/9.54G [00:05<10:15, 16.6MB/s]
#   1%|          | 52.0M/9.54G [00:05<10:37, 16.0MB/s]
#   1%|          | 56.0M/9.54G [00:05<10:00, 17.0MB/s]
#   1%|          | 60.0M/9.54G [00:05<09:40, 17.5MB/s]
#   1%|          | 63.0M/9.54G [00:06<10:00, 17.0MB/s]
#   1%|          | 67.0M/9.54G [00:06<09:43, 17.4MB/s]
#   1%|          | 71.0M/9.54G [00:06<09:27, 17.9MB/s]
#   1%|          | 74.0M/9.54G [00:06<10:02, 16.9MB/s]
#   1%|          | 78.0M/9.54G [00:07<09:57, 17.0MB/s]
#   1%|          | 82.0M/9.54G [00:07<09:54, 17.1MB/s]
#   1%|          | 85.0M/9.54G [00:07<10:22, 16.3MB/s]
#   1%|          | 89.0M/9.54G [00:07<10:01, 16.9MB/s]
#   1%|          | 92.0M/9.54G [00:07<10:43, 15.8MB/s]
#   1%|          | 94.0M/9.54G [00:08<11:58, 14.1MB/s]
#   1%|          | 98.0M/9.54G [00:08<10:50, 15.6MB/s]
#   1%|          | 102M/9.54G [00:08<10:11, 16.6MB/s]
#   1%|          | 105M/9.54G [00:08<10:23, 16.2MB/s]
#   1%|          | 109M/9.54G [00:09<09:58, 16.9MB/s]
#   1%|          | 113M/9.54G [00:09<09:37, 17.5MB/s]
#   1%|          | 116M/9.54G [00:09<09:54, 17.0MB/s]
#   1%|          | 120M/9.54G [00:09<09:39, 17.5MB/s]
#   1%|▏         | 124M/9.54G [00:09<09:25, 17.9MB/s]
#   1%|▏         | 127M/9.54G [00:10<09:46, 17.2MB/s]
#   1%|▏         | 131M/9.54G [00:10<09:31, 17.7MB/s]
#   1%|▏         | 135M/9.54G [00:10<09:21, 18.0MB/s]
#   1%|▏         | 138M/9.54G [00:10<09:44, 17.3MB/s]
#   1%|▏         | 142M/9.54G [00:10<09:29, 17.7MB/s]
#   1%|▏         | 146M/9.54G [00:11<09:32, 17.6MB/s]
#   2%|▏         | 149M/9.54G [00:11<09:51, 17.1MB/s]
#   2%|▏         | 153M/9.54G [00:11<09:47, 17.2MB/s]
#   2%|▏         | 156M/9.54G [00:11<09:54, 17.0MB/s]
#   2%|▏         | 160M/9.54G [00:12<09:32, 17.6MB/s]
#   2%|▏         | 164M/9.54G [00:12<09:32, 17.6MB/s]
#   2%|▏         | 167M/9.54G [00:12<09:40, 17.3MB/s]
#   2%|▏         | 171M/9.54G [00:12<09:39, 17.4MB/s]
#   2%|▏         | 175M/9.54G [00:12<09:24, 17.8MB/s]
#   2%|▏         | 178M/9.54G [00:13<09:47, 17.1MB/s]
#   2%|▏         | 182M/9.54G [00:13<09:55, 16.9MB/s]
#   2%|▏         | 186M/9.54G [00:13<09:49, 17.0MB/s]
#   2%|▏         | 189M/9.54G [00:13<10:04, 16.6MB/s]
#   2%|▏         | 193M/9.54G [00:14<10:11, 16.4MB/s]
#   2%|▏         | 197M/9.54G [00:14<09:55, 16.9MB/s]
#   2%|▏         | 200M/9.54G [00:14<10:10, 16.4MB/s]
#   2%|▏         | 204M/9.54G [00:14<10:11, 16.4MB/s]
#   2%|▏         | 208M/9.54G [00:15<10:26, 16.0MB/s]
#   2%|▏         | 210M/9.54G [00:15<11:44, 14.2MB/s]
#   2%|▏         | 214M/9.54G [00:15<10:59, 15.2MB/s]
#   2%|▏         | 217M/9.54G [00:15<11:10, 14.9MB/s]
#   2%|▏         | 221M/9.54G [00:16<10:23, 16.1MB/s]
#   2%|▏         | 223M/9.54G [00:16<11:50, 14.1MB/s]
#   2%|▏         | 227M/9.54G [00:16<10:51, 15.4MB/s]
#   2%|▏         | 230M/9.54G [00:16<10:49, 15.4MB/s]
#   2%|▏         | 234M/9.54G [00:16<10:08, 16.4MB/s]
#   2%|▏         | 238M/9.54G [00:17<09:45, 17.1MB/s]
#   2%|▏         | 241M/9.54G [00:17<10:00, 16.7MB/s]
#   3%|▎         | 245M/9.54G [00:17<09:37, 17.3MB/s]
#   3%|▎         | 249M/9.54G [00:17<09:34, 17.4MB/s]
#   3%|▎         | 252M/9.54G [00:17<10:09, 16.4MB/s]
#   3%|▎         | 256M/9.54G [00:18<09:51, 16.9MB/s]
#   3%|▎         | 259M/9.54G [00:18<10:21, 16.1MB/s]
#   3%|▎         | 263M/9.54G [00:18<10:04, 16.5MB/s]
#   3%|▎         | 267M/9.54G [00:18<09:49, 16.9MB/s]
#   3%|▎         | 270M/9.54G [00:19<10:17, 16.1MB/s]
#   3%|▎         | 274M/9.54G [00:19<10:03, 16.5MB/s]
#   3%|▎         | 278M/9.54G [00:19<09:50, 16.9MB/s]
#   3%|▎         | 281M/9.54G [00:19<10:17, 16.1MB/s]
#   3%|▎         | 285M/9.54G [00:20<10:04, 16.5MB/s]
#   3%|▎         | 289M/9.54G [00:20<09:54, 16.7MB/s]
#   3%|▎         | 292M/9.54G [00:20<10:19, 16.0MB/s]
#   3%|▎         | 296M/9.54G [00:20<10:02, 16.5MB/s]
#   3%|▎         | 300M/9.54G [00:21<09:39, 17.1MB/s]
#   3%|▎         | 303M/9.54G [00:21<09:53, 16.7MB/s]
#   3%|▎         | 305M/9.54G [00:21<11:18, 14.6MB/s]
#   3%|▎         | 309M/9.54G [00:21<10:25, 15.9MB/s]
#   3%|▎         | 313M/9.54G [00:21<09:51, 16.8MB/s]
#   3%|▎         | 317M/9.54G [00:22<09:44, 17.0MB/s]
#   3%|▎         | 320M/9.54G [00:22<09:38, 17.1MB/s]
#   3%|▎         | 324M/9.54G [00:22<09:21, 17.7MB/s]
#   3%|▎         | 327M/9.54G [00:22<09:43, 17.0MB/s]
#   3%|▎         | 331M/9.54G [00:22<09:24, 17.5MB/s]
#   3%|▎         | 335M/9.54G [00:23<09:12, 17.9MB/s]
#   3%|▎         | 338M/9.54G [00:23<13:03, 12.6MB/s]
#   3%|▎         | 342M/9.54G [00:23<11:38, 14.2MB/s]
#   4%|▎         | 346M/9.54G [00:24<10:42, 15.4MB/s]
#   4%|▎         | 349M/9.54G [00:24<10:43, 15.4MB/s]
#   4%|▎         | 353M/9.54G [00:24<10:05, 16.3MB/s]
#   4%|▎         | 357M/9.54G [00:24<09:40, 17.0MB/s]
#   4%|▎         | 360M/9.54G [00:24<09:55, 16.6MB/s]
#   4%|▎         | 364M/9.54G [00:25<09:32, 17.2MB/s]
#   4%|▍         | 368M/9.54G [00:25<09:17, 17.7MB/s]
#   4%|▍         | 371M/9.54G [00:25<09:39, 17.0MB/s]
#   4%|▍         | 375M/9.54G [00:25<09:20, 17.6MB/s]
#   4%|▍         | 379M/9.54G [00:26<09:09, 17.9MB/s]
#   4%|▍         | 382M/9.54G [00:26<09:32, 17.2MB/s]
#   4%|▍         | 386M/9.54G [00:26<09:51, 16.7MB/s]
#   4%|▍         | 389M/9.54G [00:26<09:45, 16.8MB/s]
#   4%|▍         | 393M/9.54G [00:26<10:00, 16.4MB/s]
#   4%|▍         | 396M/9.54G [00:27<10:00, 16.4MB/s]
#   4%|▍         | 400M/9.54G [00:27<10:09, 16.1MB/s]
#   4%|▍         | 404M/9.54G [00:27<09:53, 16.6MB/s]
#   4%|▍         | 407M/9.54G [00:27<09:54, 16.5MB/s]
#   4%|▍         | 411M/9.54G [00:28<10:05, 16.2MB/s]
#   4%|▍         | 415M/9.54G [00:28<09:39, 16.9MB/s]
#   4%|▍         | 418M/9.54G [00:28<09:43, 16.8MB/s]
#   4%|▍         | 422M/9.54G [00:28<10:01, 16.3MB/s]
#   4%|▍         | 424M/9.54G [00:29<11:13, 14.6MB/s]
#   4%|▍         | 428M/9.54G [00:29<10:20, 15.8MB/s]
#   4%|▍         | 432M/9.54G [00:29<09:47, 16.7MB/s]
#   4%|▍         | 435M/9.54G [00:29<09:59, 16.3MB/s]
#   4%|▍         | 439M/9.54G [00:29<09:34, 17.0MB/s]
#   5%|▍         | 443M/9.54G [00:30<09:17, 17.6MB/s]
#   5%|▍         | 446M/9.54G [00:30<09:35, 17.0MB/s]
#   5%|▍         | 450M/9.54G [00:30<09:19, 17.5MB/s]
#   5%|▍         | 453M/9.54G [00:30<09:37, 16.9MB/s]
#   5%|▍         | 457M/9.54G [00:30<09:19, 17.5MB/s]
#   5%|▍         | 461M/9.54G [00:31<09:06, 17.9MB/s]
#   5%|▍         | 464M/9.54G [00:31<09:29, 17.1MB/s]
#   5%|▍         | 468M/9.54G [00:31<09:12, 17.7MB/s]
#   5%|▍         | 472M/9.54G [00:31<09:02, 18.0MB/s]
#   5%|▍         | 475M/9.54G [00:32<09:23, 17.3MB/s]
#   5%|▍         | 479M/9.54G [00:32<09:10, 17.7MB/s]
#   5%|▍         | 482M/9.54G [00:32<09:30, 17.1MB/s]
#   5%|▍         | 486M/9.54G [00:32<09:25, 17.2MB/s]
#   5%|▌         | 490M/9.54G [00:32<09:22, 17.3MB/s]
#   5%|▌         | 493M/9.54G [00:33<09:52, 16.4MB/s]
#   5%|▌         | 497M/9.54G [00:33<09:41, 16.7MB/s]
#   5%|▌         | 501M/9.54G [00:33<09:33, 16.9MB/s]
#   5%|▌         | 504M/9.54G [00:33<09:59, 16.2MB/s]
#   5%|▌         | 508M/9.54G [00:34<09:44, 16.6MB/s]
#   5%|▌         | 512M/9.54G [00:34<09:35, 16.9MB/s]
#   5%|▌         | 515M/9.54G [00:34<10:00, 16.2MB/s]
#   5%|▌         | 519M/9.54G [00:34<09:46, 16.5MB/s]
#   5%|▌         | 522M/9.54G [00:35<10:09, 15.9MB/s]
#   5%|▌         | 526M/9.54G [00:35<09:39, 16.7MB/s]
#   5%|▌         | 530M/9.54G [00:35<09:19, 17.3MB/s]
#   5%|▌         | 533M/9.54G [00:35<09:36, 16.8MB/s]
#   5%|▌         | 537M/9.54G [00:35<09:16, 17.4MB/s]
#   6%|▌         | 541M/9.54G [00:36<09:37, 16.8MB/s]
#   6%|▌         | 544M/9.54G [00:36<09:55, 16.2MB/s]
#   6%|▌         | 547M/9.54G [00:36<10:05, 16.0MB/s]
#   6%|▌         | 551M/9.54G [00:36<09:47, 16.4MB/s]
#   6%|▌         | 555M/9.54G [00:37<09:23, 17.2MB/s]
#   6%|▌         | 558M/9.54G [00:37<09:26, 17.0MB/s]
#   6%|▌         | 562M/9.54G [00:37<09:22, 17.2MB/s]
#   6%|▌         | 566M/9.54G [00:37<09:26, 17.0MB/s]
#   6%|▌         | 568M/9.54G [00:37<10:54, 14.7MB/s]
#   6%|▌         | 572M/9.54G [00:38<10:18, 15.6MB/s]
#   6%|▌         | 575M/9.54G [00:38<09:59, 16.1MB/s]
#   6%|▌         | 579M/9.54G [00:38<10:15, 15.7MB/s]
#   6%|▌         | 583M/9.54G [00:38<09:53, 16.2MB/s]
#   6%|▌         | 586M/9.54G [00:39<09:40, 16.6MB/s]
#   6%|▌         | 590M/9.54G [00:39<10:02, 16.0MB/s]
#   6%|▌         | 594M/9.54G [00:39<09:45, 16.4MB/s]
#   6%|▌         | 597M/9.54G [00:39<09:34, 16.7MB/s]
#   6%|▌         | 601M/9.54G [00:40<09:58, 16.1MB/s]
#   6%|▌         | 604M/9.54G [00:40<09:44, 16.4MB/s]
#   6%|▌         | 608M/9.54G [00:40<09:31, 16.8MB/s]
#   6%|▋         | 612M/9.54G [00:40<09:55, 16.1MB/s]
#   6%|▋         | 615M/9.54G [00:40<09:42, 16.5MB/s]
#   6%|▋         | 619M/9.54G [00:41<10:03, 15.9MB/s]
#   6%|▋         | 623M/9.54G [00:41<09:45, 16.4MB/s]
#   6%|▋         | 626M/9.54G [00:41<09:34, 16.7MB/s]
#   6%|▋         | 630M/9.54G [00:41<09:56, 16.1MB/s]
#   6%|▋         | 634M/9.54G [00:42<09:41, 16.5MB/s]
#   7%|▋         | 637M/9.54G [00:42<09:18, 17.2MB/s]
#   7%|▋         | 641M/9.54G [00:42<09:34, 16.7MB/s]
#   7%|▋         | 644M/9.54G [00:42<09:13, 17.3MB/s]
#   7%|▋         | 648M/9.54G [00:43<09:52, 16.2MB/s]
#   7%|▋         | 650M/9.54G [00:43<11:03, 14.4MB/s]
#   7%|▋         | 654M/9.54G [00:43<10:09, 15.7MB/s]
#   7%|▋         | 658M/9.54G [00:43<09:34, 16.6MB/s]
#   7%|▋         | 661M/9.54G [00:43<09:47, 16.3MB/s]
#   7%|▋         | 665M/9.54G [00:44<09:20, 17.0MB/s]
#   7%|▋         | 669M/9.54G [00:44<09:02, 17.6MB/s]
#   7%|▋         | 672M/9.54G [00:44<09:23, 16.9MB/s]
#   7%|▋         | 676M/9.54G [00:44<09:04, 17.5MB/s]
#   7%|▋         | 680M/9.54G [00:45<09:04, 17.5MB/s]
#   7%|▋         | 683M/9.54G [00:45<09:35, 16.5MB/s]
#   7%|▋         | 687M/9.54G [00:45<09:25, 16.9MB/s]
#   7%|▋         | 691M/9.54G [00:45<09:17, 17.1MB/s]
#   7%|▋         | 694M/9.54G [00:45<09:46, 16.2MB/s]
#   7%|▋         | 696M/9.54G [00:46<15:26, 10.3MB/s]
#   7%|▋         | 699M/9.54G [00:46<14:01, 11.3MB/s]
#   7%|▋         | 702M/9.54G [00:46<13:07, 12.1MB/s]
#   7%|▋         | 706M/9.54G [00:47<11:38, 13.6MB/s]
#   7%|▋         | 710M/9.54G [00:47<10:45, 14.7MB/s]
#   7%|▋         | 713M/9.54G [00:47<10:50, 14.6MB/s]
#   7%|▋         | 717M/9.54G [00:47<10:01, 15.8MB/s]
#   7%|▋         | 721M/9.54G [00:48<09:42, 16.3MB/s]
#   7%|▋         | 724M/9.54G [00:48<10:03, 15.7MB/s]
#   7%|▋         | 728M/9.54G [00:48<09:42, 16.3MB/s]
#   7%|▋         | 732M/9.54G [00:48<09:29, 16.6MB/s]
#   8%|▊         | 735M/9.54G [00:48<09:54, 15.9MB/s]
#   8%|▊         | 739M/9.54G [00:49<09:57, 15.9MB/s]
#   8%|▊         | 742M/9.54G [00:49<10:07, 15.6MB/s]
#   8%|▊         | 746M/9.54G [00:49<09:32, 16.5MB/s]
#   8%|▊         | 749M/9.54G [00:49<09:45, 16.2MB/s]
#   8%|▊         | 753M/9.54G [00:50<09:37, 16.4MB/s]
#   8%|▊         | 755M/9.54G [00:50<10:48, 14.6MB/s]
#   8%|▊         | 759M/9.54G [00:50<09:55, 15.9MB/s]
#   8%|▊         | 763M/9.54G [00:50<09:37, 16.4MB/s]
#   8%|▊         | 766M/9.54G [00:51<10:00, 15.7MB/s]
#   8%|▊         | 770M/9.54G [00:51<09:39, 16.3MB/s]
#   8%|▊         | 774M/9.54G [00:51<09:26, 16.7MB/s]
#   8%|▊         | 777M/9.54G [00:51<09:50, 16.0MB/s]
#   8%|▊         | 781M/9.54G [00:51<09:33, 16.5MB/s]
#   8%|▊         | 785M/9.54G [00:52<09:21, 16.8MB/s]
#   8%|▊         | 788M/9.54G [00:52<09:46, 16.1MB/s]
#   8%|▊         | 792M/9.54G [00:52<09:29, 16.5MB/s]
#   8%|▊         | 796M/9.54G [00:52<09:19, 16.8MB/s]
#   8%|▊         | 799M/9.54G [00:53<09:44, 16.1MB/s]
#   8%|▊         | 803M/9.54G [00:53<09:28, 16.5MB/s]
#   8%|▊         | 807M/9.54G [00:53<09:19, 16.8MB/s]
#   8%|▊         | 810M/9.54G [00:53<09:44, 16.1MB/s]
#   8%|▊         | 814M/9.54G [00:54<09:28, 16.5MB/s]
#   8%|▊         | 818M/9.54G [00:54<09:18, 16.8MB/s]
#   8%|▊         | 821M/9.54G [00:54<09:42, 16.1MB/s]
#   8%|▊         | 825M/9.54G [00:54<09:27, 16.5MB/s]
#   8%|▊         | 828M/9.54G [00:54<09:51, 15.9MB/s]
#   9%|▊         | 832M/9.54G [00:55<09:32, 16.4MB/s]
#   9%|▊         | 836M/9.54G [00:55<09:50, 15.9MB/s]
#   9%|▊         | 838M/9.54G [00:55<10:59, 14.2MB/s]
#   9%|▊         | 842M/9.54G [00:55<10:14, 15.2MB/s]
#   9%|▊         | 846M/9.54G [00:56<09:48, 15.9MB/s]
#   9%|▊         | 849M/9.54G [00:56<10:05, 15.4MB/s]
#   9%|▊         | 853M/9.54G [00:56<09:41, 16.1MB/s]
#   9%|▉         | 856M/9.54G [00:56<10:00, 15.6MB/s]
#   9%|▉         | 860M/9.54G [00:57<09:38, 16.2MB/s]
#   9%|▉         | 864M/9.54G [00:57<09:11, 16.9MB/s]
#   9%|▉         | 867M/9.54G [00:57<09:26, 16.5MB/s]
#   9%|▉         | 871M/9.54G [00:57<09:03, 17.2MB/s]
#   9%|▉         | 875M/9.54G [00:57<08:48, 17.7MB/s]
#   9%|▉         | 878M/9.54G [00:58<09:08, 17.0MB/s]
#   9%|▉         | 882M/9.54G [00:58<08:50, 17.6MB/s]
#   9%|▉         | 886M/9.54G [00:58<08:38, 18.0MB/s]
#   9%|▉         | 889M/9.54G [00:58<09:01, 17.2MB/s]
#   9%|▉         | 893M/9.54G [00:59<08:46, 17.7MB/s]
#   9%|▉         | 897M/9.54G [00:59<08:36, 18.0MB/s]
#   9%|▉         | 900M/9.54G [00:59<08:58, 17.3MB/s]
#   9%|▉         | 904M/9.54G [00:59<08:44, 17.7MB/s]
#   9%|▉         | 908M/9.54G [00:59<08:34, 18.1MB/s]
#   9%|▉         | 911M/9.54G [01:00<08:57, 17.3MB/s]
#   9%|▉         | 915M/9.54G [01:00<08:43, 17.8MB/s]
#   9%|▉         | 919M/9.54G [01:00<08:45, 17.7MB/s]
#   9%|▉         | 922M/9.54G [01:00<09:16, 16.7MB/s]
#   9%|▉         | 926M/9.54G [01:01<09:07, 16.9MB/s]
#  10%|▉         | 930M/9.54G [01:01<09:02, 17.1MB/s]
#  10%|▉         | 933M/9.54G [01:01<09:29, 16.3MB/s]
#  10%|▉         | 937M/9.54G [01:01<09:17, 16.6MB/s]
#  10%|▉         | 940M/9.54G [01:02<09:40, 16.0MB/s]
#  10%|▉         | 944M/9.54G [01:02<09:23, 16.4MB/s]
#  10%|▉         | 948M/9.54G [01:02<09:11, 16.8MB/s]
#  10%|▉         | 951M/9.54G [01:02<09:37, 16.0MB/s]
#  10%|▉         | 955M/9.54G [01:02<09:09, 16.8MB/s]
#  10%|▉         | 959M/9.54G [01:03<08:50, 17.4MB/s]
#  10%|▉         | 962M/9.54G [01:03<09:08, 16.8MB/s]
#  10%|▉         | 966M/9.54G [01:03<08:49, 17.4MB/s]
#  10%|▉         | 970M/9.54G [01:03<08:37, 17.8MB/s]
#  10%|▉         | 973M/9.54G [01:04<08:59, 17.1MB/s]
#  10%|▉         | 977M/9.54G [01:04<08:44, 17.6MB/s]
#  10%|█         | 981M/9.54G [01:04<08:42, 17.6MB/s]
#  10%|█         | 984M/9.54G [01:04<08:50, 17.4MB/s]
#  10%|█         | 987M/9.54G [01:04<07:49, 19.6MB/s]
#  10%|█         | 990M/9.54G [01:04<08:13, 18.7MB/s]
#  10%|█         | 992M/9.54G [01:05<09:34, 16.0MB/s]
#  10%|█         | 995M/9.54G [01:05<09:42, 15.8MB/s]
#  10%|█         | 998M/9.54G [01:05<08:16, 18.5MB/s]
#  10%|█         | 0.98G/9.54G [01:05<09:14, 16.6MB/s]
#  10%|█         | 0.98G/9.54G [01:05<10:17, 14.9MB/s]
#  10%|█         | 0.98G/9.54G [01:06<09:38, 15.9MB/s]
#  10%|█         | 0.99G/9.54G [01:06<09:18, 16.4MB/s]
#  10%|█         | 0.99G/9.54G [01:06<09:43, 15.7MB/s]
#  10%|█         | 0.99G/9.54G [01:07<14:41, 10.4MB/s]
#  10%|█         | 1.00G/9.54G [01:07<12:34, 12.2MB/s]
#  10%|█         | 1.00G/9.54G [01:07<11:16, 13.6MB/s]
#  11%|█         | 1.00G/9.54G [01:07<11:08, 13.7MB/s]
#  11%|█         | 1.01G/9.54G [01:08<10:21, 14.8MB/s]
#  11%|█         | 1.01G/9.54G [01:08<09:46, 15.6MB/s]
#  11%|█         | 1.01G/9.54G [01:08<10:03, 15.2MB/s]
#  11%|█         | 1.02G/9.54G [01:08<09:34, 15.9MB/s]
#  11%|█         | 1.02G/9.54G [01:08<10:13, 14.9MB/s]
#  11%|█         | 1.02G/9.54G [01:09<10:38, 14.3MB/s]
#  11%|█         | 1.03G/9.54G [01:09<10:04, 15.1MB/s]
#  11%|█         | 1.03G/9.54G [01:09<11:17, 13.5MB/s]
#  11%|█         | 1.03G/9.54G [01:09<10:08, 15.0MB/s]
#  11%|█         | 1.04G/9.54G [01:10<10:04, 15.1MB/s]
#  11%|█         | 1.04G/9.54G [01:10<09:23, 16.2MB/s]
#  11%|█         | 1.04G/9.54G [01:10<09:31, 16.0MB/s]
#  11%|█         | 1.05G/9.54G [01:10<09:02, 16.8MB/s]
#  11%|█         | 1.05G/9.54G [01:10<08:44, 17.4MB/s]
#  11%|█         | 1.05G/9.54G [01:11<09:01, 16.8MB/s]
#  11%|█         | 1.06G/9.54G [01:11<08:43, 17.4MB/s]
#  11%|█         | 1.06G/9.54G [01:11<08:30, 17.8MB/s]
#  11%|█         | 1.06G/9.54G [01:11<08:51, 17.1MB/s]
#  11%|█         | 1.07G/9.54G [01:12<08:35, 17.6MB/s]
#  11%|█         | 1.07G/9.54G [01:12<08:26, 18.0MB/s]
#  11%|█▏        | 1.08G/9.54G [01:12<08:47, 17.2MB/s]
#  11%|█▏        | 1.08G/9.54G [01:12<08:45, 17.3MB/s]
#  11%|█▏        | 1.08G/9.54G [01:12<09:14, 16.4MB/s]
#  11%|█▏        | 1.09G/9.54G [01:13<09:02, 16.8MB/s]
#  11%|█▏        | 1.09G/9.54G [01:13<08:54, 17.0MB/s]
#  11%|█▏        | 1.09G/9.54G [01:13<09:21, 16.2MB/s]
#  11%|█▏        | 1.10G/9.54G [01:13<09:06, 16.6MB/s]
#  12%|█▏        | 1.10G/9.54G [01:14<08:57, 16.9MB/s]
#  12%|█▏        | 1.10G/9.54G [01:14<09:22, 16.1MB/s]
#  12%|█▏        | 1.11G/9.54G [01:14<09:07, 16.5MB/s]
#  12%|█▏        | 1.11G/9.54G [01:14<08:56, 16.9MB/s]
#  12%|█▏        | 1.11G/9.54G [01:15<09:23, 16.1MB/s]
#  12%|█▏        | 1.12G/9.54G [01:15<09:06, 16.5MB/s]
#  12%|█▏        | 1.12G/9.54G [01:15<09:31, 15.8MB/s]
#  12%|█▏        | 1.12G/9.54G [01:15<09:11, 16.4MB/s]
#  12%|█▏        | 1.13G/9.54G [01:15<09:00, 16.7MB/s]
#  12%|█▏        | 1.13G/9.54G [01:16<10:23, 14.5MB/s]
#  12%|█▏        | 1.13G/9.54G [01:16<09:45, 15.4MB/s]
#  12%|█▏        | 1.14G/9.54G [01:16<09:46, 15.4MB/s]
#  12%|█▏        | 1.14G/9.54G [01:16<09:22, 16.0MB/s]
#  12%|█▏        | 1.15G/9.54G [01:17<09:06, 16.5MB/s]
#  12%|█▏        | 1.15G/9.54G [01:17<09:28, 15.8MB/s]
#  12%|█▏        | 1.15G/9.54G [01:17<09:49, 15.3MB/s]
#  12%|█▏        | 1.16G/9.54G [01:17<10:05, 14.9MB/s]
#  12%|█▏        | 1.16G/9.54G [01:18<09:34, 15.7MB/s]
#  12%|█▏        | 1.16G/9.54G [01:18<09:15, 16.2MB/s]
#  12%|█▏        | 1.17G/9.54G [01:18<09:35, 15.6MB/s]
#  12%|█▏        | 1.17G/9.54G [01:18<09:15, 16.2MB/s]
#  12%|█▏        | 1.17G/9.54G [01:19<09:35, 15.6MB/s]
#  12%|█▏        | 1.18G/9.54G [01:19<09:13, 16.2MB/s]
#  12%|█▏        | 1.18G/9.54G [01:19<09:00, 16.6MB/s]
#  12%|█▏        | 1.18G/9.54G [01:19<09:23, 15.9MB/s]
#  12%|█▏        | 1.19G/9.54G [01:19<09:06, 16.4MB/s]
#  12%|█▏        | 1.19G/9.54G [01:20<08:56, 16.7MB/s]
#  13%|█▎        | 1.19G/9.54G [01:20<09:18, 16.0MB/s]
#  13%|█▎        | 1.20G/9.54G [01:20<08:52, 16.8MB/s]
#  13%|█▎        | 1.20G/9.54G [01:20<08:34, 17.4MB/s]
#  13%|█▎        | 1.21G/9.54G [01:21<08:51, 16.8MB/s]
#  13%|█▎        | 1.21G/9.54G [01:21<08:34, 17.4MB/s]
#  13%|█▎        | 1.21G/9.54G [01:21<08:21, 17.8MB/s]
#  13%|█▎        | 1.22G/9.54G [01:21<08:43, 17.1MB/s]
#  13%|█▎        | 1.22G/9.54G [01:21<08:38, 17.2MB/s]
#  13%|█▎        | 1.22G/9.54G [01:22<08:35, 17.3MB/s]
#  13%|█▎        | 1.23G/9.54G [01:22<08:50, 16.8MB/s]
#  13%|█▎        | 1.23G/9.54G [01:22<08:55, 16.7MB/s]
#  13%|█▎        | 1.23G/9.54G [01:22<08:46, 16.9MB/s]
#  13%|█▎        | 1.24G/9.54G [01:23<08:49, 16.9MB/s]
#  13%|█▎        | 1.24G/9.54G [01:23<09:04, 16.4MB/s]
#  13%|█▎        | 1.24G/9.54G [01:23<09:01, 16.4MB/s]
#  13%|█▎        | 1.25G/9.54G [01:23<08:49, 16.8MB/s]
#  13%|█▎        | 1.25G/9.54G [01:24<09:05, 16.3MB/s]
#  13%|█▎        | 1.25G/9.54G [01:24<09:02, 16.4MB/s]
#  13%|█▎        | 1.26G/9.54G [01:24<09:02, 16.4MB/s]
#  13%|█▎        | 1.26G/9.54G [01:24<08:39, 17.1MB/s]
#  13%|█▎        | 1.27G/9.54G [01:24<08:54, 16.6MB/s]
#  13%|█▎        | 1.27G/9.54G [01:25<08:56, 16.5MB/s]
#  13%|█▎        | 1.27G/9.54G [01:25<08:47, 16.8MB/s]
#  13%|█▎        | 1.28G/9.54G [01:25<08:59, 16.5MB/s]
#  13%|█▎        | 1.28G/9.54G [01:25<08:59, 16.4MB/s]
#  13%|█▎        | 1.28G/9.54G [01:26<10:07, 14.6MB/s]
#  13%|█▎        | 1.28G/9.54G [01:26<15:31, 9.52MB/s]
#  13%|█▎        | 1.29G/9.54G [01:26<12:36, 11.7MB/s]
#  14%|█▎        | 1.29G/9.54G [01:27<11:02, 13.4MB/s]
#  14%|█▎        | 1.29G/9.54G [01:27<11:50, 12.5MB/s]
#  14%|█▎        | 1.30G/9.54G [01:27<11:10, 13.2MB/s]
#  14%|█▎        | 1.30G/9.54G [01:27<09:58, 14.8MB/s]
#  14%|█▎        | 1.30G/9.54G [01:27<09:14, 16.0MB/s]
#  14%|█▎        | 1.31G/9.54G [01:28<09:19, 15.8MB/s]
#  14%|█▎        | 1.31G/9.54G [01:28<08:50, 16.7MB/s]
#  14%|█▍        | 1.32G/9.54G [01:28<08:30, 17.3MB/s]
#  14%|█▍        | 1.32G/9.54G [01:28<08:46, 16.8MB/s]
#  14%|█▍        | 1.32G/9.54G [01:29<08:27, 17.4MB/s]
#  14%|█▍        | 1.33G/9.54G [01:29<08:15, 17.8MB/s]
#  14%|█▍        | 1.33G/9.54G [01:29<08:34, 17.1MB/s]
#  14%|█▍        | 1.33G/9.54G [01:29<08:20, 17.6MB/s]
#  14%|█▍        | 1.34G/9.54G [01:29<08:10, 18.0MB/s]
#  14%|█▍        | 1.34G/9.54G [01:30<08:30, 17.2MB/s]
#  14%|█▍        | 1.34G/9.54G [01:30<08:17, 17.7MB/s]
#  14%|█▍        | 1.35G/9.54G [01:30<08:36, 17.0MB/s]
#  14%|█▍        | 1.35G/9.54G [01:30<08:20, 17.6MB/s]
#  14%|█▍        | 1.35G/9.54G [01:31<08:21, 17.5MB/s]
#  14%|█▍        | 1.36G/9.54G [01:31<08:49, 16.6MB/s]
#  14%|█▍        | 1.36G/9.54G [01:31<08:42, 16.8MB/s]
#  14%|█▍        | 1.37G/9.54G [01:31<08:37, 17.0MB/s]
#  14%|█▍        | 1.37G/9.54G [01:31<08:58, 16.3MB/s]
#  14%|█▍        | 1.37G/9.54G [01:32<08:47, 16.6MB/s]
#  14%|█▍        | 1.38G/9.54G [01:32<08:38, 16.9MB/s]
#  14%|█▍        | 1.38G/9.54G [01:32<09:00, 16.2MB/s]
#  14%|█▍        | 1.38G/9.54G [01:32<08:49, 16.5MB/s]
#  15%|█▍        | 1.39G/9.54G [01:33<08:58, 16.3MB/s]
#  15%|█▍        | 1.39G/9.54G [01:33<08:34, 17.0MB/s]
#  15%|█▍        | 1.39G/9.54G [01:33<08:19, 17.5MB/s]
#  15%|█▍        | 1.40G/9.54G [01:33<08:35, 17.0MB/s]
#  15%|█▍        | 1.40G/9.54G [01:33<08:21, 17.4MB/s]
#  15%|█▍        | 1.40G/9.54G [01:34<08:09, 17.9MB/s]
#  15%|█▍        | 1.41G/9.54G [01:34<08:27, 17.2MB/s]
#  15%|█▍        | 1.41G/9.54G [01:34<08:15, 17.6MB/s]
#  15%|█▍        | 1.42G/9.54G [01:34<08:05, 18.0MB/s]
#  15%|█▍        | 1.42G/9.54G [01:35<08:23, 17.3MB/s]
#  15%|█▍        | 1.42G/9.54G [01:35<08:23, 17.3MB/s]
#  15%|█▍        | 1.43G/9.54G [01:35<08:21, 17.4MB/s]
#  15%|█▍        | 1.43G/9.54G [01:35<08:46, 16.6MB/s]
#  15%|█▌        | 1.43G/9.54G [01:35<08:39, 16.8MB/s]
#  15%|█▌        | 1.44G/9.54G [01:36<09:00, 16.1MB/s]
#  15%|█▌        | 1.44G/9.54G [01:36<08:48, 16.5MB/s]
#  15%|█▌        | 1.44G/9.54G [01:36<08:38, 16.8MB/s]
#  15%|█▌        | 1.45G/9.54G [01:36<08:58, 16.1MB/s]
#  15%|█▌        | 1.45G/9.54G [01:37<08:47, 16.5MB/s]
#  15%|█▌        | 1.45G/9.54G [01:37<08:37, 16.8MB/s]
#  15%|█▌        | 1.46G/9.54G [01:37<13:12, 11.0MB/s]
#  15%|█▌        | 1.46G/9.54G [01:38<11:20, 12.8MB/s]
#  15%|█▌        | 1.46G/9.54G [01:38<10:53, 13.3MB/s]
#  15%|█▌        | 1.46G/9.54G [01:38<11:56, 12.1MB/s]
#  15%|█▌        | 1.47G/9.54G [01:38<10:21, 14.0MB/s]
#  15%|█▌        | 1.47G/9.54G [01:38<09:26, 15.3MB/s]
#  15%|█▌        | 1.48G/9.54G [01:39<09:25, 15.3MB/s]
#  15%|█▌        | 1.48G/9.54G [01:39<09:58, 14.5MB/s]
#  16%|█▌        | 1.48G/9.54G [01:39<11:08, 12.9MB/s]
#  16%|█▌        | 1.48G/9.54G [01:39<10:02, 14.4MB/s]
#  16%|█▌        | 1.49G/9.54G [01:40<09:24, 15.3MB/s]
#  16%|█▌        | 1.49G/9.54G [01:40<09:00, 16.0MB/s]
#  16%|█▌        | 1.50G/9.54G [01:40<09:07, 15.8MB/s]
#  16%|█▌        | 1.50G/9.54G [01:40<08:37, 16.7MB/s]
#  16%|█▌        | 1.50G/9.54G [01:40<08:49, 16.3MB/s]
#  16%|█▌        | 1.51G/9.54G [01:41<08:26, 17.1MB/s]
#  16%|█▌        | 1.51G/9.54G [01:41<08:10, 17.6MB/s]
#  16%|█▌        | 1.51G/9.54G [01:41<08:29, 16.9MB/s]
#  16%|█▌        | 1.52G/9.54G [01:41<08:14, 17.4MB/s]
#  16%|█▌        | 1.52G/9.54G [01:42<08:12, 17.5MB/s]
#  16%|█▌        | 1.52G/9.54G [01:42<08:40, 16.5MB/s]
#  16%|█▌        | 1.53G/9.54G [01:42<08:30, 16.9MB/s]
#  16%|█▌        | 1.53G/9.54G [01:43<12:35, 11.4MB/s]
#  16%|█▌        | 1.53G/9.54G [01:43<10:57, 13.1MB/s]
#  16%|█▌        | 1.54G/9.54G [01:43<09:52, 14.5MB/s]
#  16%|█▌        | 1.54G/9.54G [01:43<09:44, 14.7MB/s]
#  16%|█▌        | 1.54G/9.54G [01:43<09:02, 15.8MB/s]
#  16%|█▌        | 1.55G/9.54G [01:44<08:34, 16.7MB/s]
#  16%|█▋        | 1.55G/9.54G [01:44<08:45, 16.3MB/s]
#  16%|█▋        | 1.56G/9.54G [01:44<08:23, 17.0MB/s]
#  16%|█▋        | 1.56G/9.54G [01:45<11:56, 12.0MB/s]
#  16%|█▋        | 1.56G/9.54G [01:45<10:28, 13.6MB/s]
#  16%|█▋        | 1.57G/9.54G [01:45<09:33, 14.9MB/s]
#  16%|█▋        | 1.57G/9.54G [01:45<09:29, 15.0MB/s]
#  16%|█▋        | 1.57G/9.54G [01:45<08:51, 16.1MB/s]
#  17%|█▋        | 1.58G/9.54G [01:46<08:27, 16.8MB/s]
#  17%|█▋        | 1.58G/9.54G [01:46<08:40, 16.4MB/s]
#  17%|█▋        | 1.58G/9.54G [01:46<08:29, 16.8MB/s]
#  17%|█▋        | 1.59G/9.54G [01:46<09:37, 14.8MB/s]
#  17%|█▋        | 1.59G/9.54G [01:47<08:53, 16.0MB/s]
#  17%|█▋        | 1.59G/9.54G [01:47<08:38, 16.5MB/s]
#  17%|█▋        | 1.60G/9.54G [01:47<08:48, 16.2MB/s]
#  17%|█▋        | 1.60G/9.54G [01:47<08:23, 17.0MB/s]
#  17%|█▋        | 1.60G/9.54G [01:47<08:17, 17.1MB/s]
#  17%|█▋        | 1.61G/9.54G [01:48<08:42, 16.3MB/s]
#  17%|█▋        | 1.61G/9.54G [01:48<08:30, 16.7MB/s]
#  17%|█▋        | 1.62G/9.54G [01:48<08:23, 16.9MB/s]
#  17%|█▋        | 1.62G/9.54G [01:48<08:46, 16.2MB/s]
#  17%|█▋        | 1.62G/9.54G [01:49<08:33, 16.6MB/s]
#  17%|█▋        | 1.63G/9.54G [01:49<08:24, 16.9MB/s]
#  17%|█▋        | 1.63G/9.54G [01:49<08:46, 16.1MB/s]
#  17%|█▋        | 1.63G/9.54G [01:49<08:22, 16.9MB/s]
#  17%|█▋        | 1.64G/9.54G [01:50<08:35, 16.5MB/s]
#  17%|█▋        | 1.64G/9.54G [01:50<08:14, 17.2MB/s]
#  17%|█▋        | 1.64G/9.54G [01:50<08:10, 17.3MB/s]
#  17%|█▋        | 1.65G/9.54G [01:50<08:37, 16.4MB/s]
#  17%|█▋        | 1.65G/9.54G [01:50<08:26, 16.7MB/s]
#  17%|█▋        | 1.65G/9.54G [01:51<08:19, 17.0MB/s]
#  17%|█▋        | 1.66G/9.54G [01:51<08:03, 17.5MB/s]
#  17%|█▋        | 1.66G/9.54G [01:51<08:23, 16.8MB/s]
#  17%|█▋        | 1.66G/9.54G [01:51<08:03, 17.5MB/s]
#  17%|█▋        | 1.66G/9.54G [01:51<09:26, 14.9MB/s]
#  17%|█▋        | 1.66G/9.54G [01:51<09:19, 15.1MB/s]
#  17%|█▋        | 1.67G/9.54G [01:52<10:58, 12.8MB/s]
#  17%|█▋        | 1.67G/9.54G [01:52<10:20, 13.6MB/s]
#  17%|█▋        | 1.67G/9.54G [01:52<09:28, 14.9MB/s]
#  18%|█▊        | 1.67G/9.54G [01:52<09:15, 15.2MB/s]
#  18%|█▊        | 1.67G/9.54G [01:52<08:41, 16.2MB/s]
#  18%|█▊        | 1.68G/9.54G [01:52<08:42, 16.2MB/s]
#  18%|█▊        | 1.68G/9.54G [01:52<08:20, 16.9MB/s]
#  18%|█▊        | 1.68G/9.54G [01:52<08:24, 16.7MB/s]
#  18%|█▊        | 1.68G/9.54G [01:53<08:42, 16.2MB/s]
#  18%|█▊        | 1.69G/9.54G [01:53<09:07, 15.4MB/s]
#  18%|█▊        | 1.69G/9.54G [01:53<08:28, 16.6MB/s]
#  18%|█▊        | 1.69G/9.54G [01:53<08:05, 17.4MB/s]
#  18%|█▊        | 1.70G/9.54G [01:54<08:23, 16.7MB/s]
#  18%|█▊        | 1.70G/9.54G [01:54<07:26, 18.8MB/s]
#  18%|█▊        | 1.70G/9.54G [01:54<07:53, 17.8MB/s]
#  18%|█▊        | 1.70G/9.54G [01:54<08:17, 16.9MB/s]
#  18%|█▊        | 1.71G/9.54G [01:54<08:33, 16.4MB/s]
#  18%|█▊        | 1.71G/9.54G [01:54<08:14, 17.0MB/s]
#  18%|█▊        | 1.71G/9.54G [01:54<08:22, 16.7MB/s]
#  18%|█▊        | 1.71G/9.54G [01:55<08:03, 17.4MB/s]
#  18%|█▊        | 1.71G/9.54G [01:55<08:31, 16.4MB/s]
#  18%|█▊        | 1.72G/9.54G [01:55<08:44, 16.0MB/s]
#  18%|█▊        | 1.72G/9.54G [01:55<08:21, 16.7MB/s]
#  18%|█▊        | 1.72G/9.54G [01:55<08:28, 16.5MB/s]
#  18%|█▊        | 1.72G/9.54G [01:55<07:12, 19.4MB/s]
#  18%|█▊        | 1.73G/9.54G [01:55<07:47, 17.9MB/s]
#  18%|█▊        | 1.73G/9.54G [01:56<09:05, 15.4MB/s]
#  18%|█▊        | 1.73G/9.54G [01:56<08:33, 16.3MB/s]
#  18%|█▊        | 1.73G/9.54G [01:56<08:37, 16.2MB/s]
#  18%|█▊        | 1.73G/9.54G [01:56<08:11, 17.0MB/s]
#  18%|█▊        | 1.74G/9.54G [01:56<08:40, 16.1MB/s]
#  18%|█▊        | 1.74G/9.54G [01:56<08:50, 15.8MB/s]
#  18%|█▊        | 1.74G/9.54G [01:56<08:23, 16.6MB/s]
#  18%|█▊        | 1.74G/9.54G [01:57<08:12, 17.0MB/s]
#  18%|█▊        | 1.75G/9.54G [01:57<07:54, 17.7MB/s]
#  18%|█▊        | 1.75G/9.54G [01:57<08:25, 16.6MB/s]
#  18%|█▊        | 1.75G/9.54G [01:57<08:27, 16.5MB/s]
#  18%|█▊        | 1.75G/9.54G [01:57<08:22, 16.7MB/s]
#  18%|█▊        | 1.75G/9.54G [01:57<08:46, 15.9MB/s]
#  18%|█▊        | 1.76G/9.54G [01:57<08:35, 16.2MB/s]
#  18%|█▊        | 1.76G/9.54G [01:58<08:30, 16.4MB/s]
#  18%|█▊        | 1.76G/9.54G [01:58<08:01, 17.3MB/s]
#  18%|█▊        | 1.76G/9.54G [01:58<08:02, 17.3MB/s]
#  18%|█▊        | 1.76G/9.54G [01:58<09:46, 14.2MB/s]
#  19%|█▊        | 1.77G/9.54G [01:58<09:57, 14.0MB/s]
#  19%|█▊        | 1.77G/9.54G [01:58<09:37, 14.5MB/s]
#  19%|█▊        | 1.77G/9.54G [01:59<08:40, 16.0MB/s]
#  19%|█▊        | 1.78G/9.54G [01:59<09:00, 15.4MB/s]
#  19%|█▊        | 1.78G/9.54G [01:59<08:36, 16.1MB/s]
#  19%|█▊        | 1.78G/9.54G [01:59<08:42, 15.9MB/s]
#  19%|█▊        | 1.78G/9.54G [01:59<08:20, 16.7MB/s]
#  19%|█▊        | 1.78G/9.54G [01:59<09:45, 14.2MB/s]
#  19%|█▊        | 1.79G/9.54G [01:59<08:30, 16.3MB/s]
#  19%|█▊        | 1.79G/9.54G [02:00<08:11, 16.9MB/s]
#  19%|█▉        | 1.79G/9.54G [02:00<08:18, 16.7MB/s]
#  19%|█▉        | 1.79G/9.54G [02:00<08:00, 17.3MB/s]
#  19%|█▉        | 1.79G/9.54G [02:00<09:15, 15.0MB/s]
#  19%|█▉        | 1.80G/9.54G [02:00<07:55, 17.5MB/s]
#  19%|█▉        | 1.80G/9.54G [02:00<07:44, 17.9MB/s]
#  19%|█▉        | 1.80G/9.54G [02:00<07:41, 18.0MB/s]
#  19%|█▉        | 1.80G/9.54G [02:01<07:33, 18.3MB/s]
#  19%|█▉        | 1.81G/9.54G [02:01<08:55, 15.5MB/s]
#  19%|█▉        | 1.81G/9.54G [02:01<08:00, 17.3MB/s]
#  19%|█▉        | 1.81G/9.54G [02:01<08:22, 16.5MB/s]
#  19%|█▉        | 1.81G/9.54G [02:01<07:12, 19.2MB/s]
#  19%|█▉        | 1.82G/9.54G [02:01<08:29, 16.3MB/s]
#  19%|█▉        | 1.82G/9.54G [02:01<07:47, 17.7MB/s]
#  19%|█▉        | 1.82G/9.54G [02:02<08:11, 16.9MB/s]
#  19%|█▉        | 1.83G/9.54G [02:02<07:06, 19.4MB/s]
#  19%|█▉        | 1.83G/9.54G [02:02<07:42, 17.9MB/s]
#  19%|█▉        | 1.83G/9.54G [02:02<07:55, 17.4MB/s]
#  19%|█▉        | 1.83G/9.54G [02:02<08:14, 16.7MB/s]
#  19%|█▉        | 1.84G/9.54G [02:02<07:10, 19.2MB/s]
#  19%|█▉        | 1.84G/9.54G [02:03<08:21, 16.5MB/s]
#  19%|█▉        | 1.84G/9.54G [02:03<07:44, 17.8MB/s]
#  19%|█▉        | 1.84G/9.54G [02:03<08:08, 16.9MB/s]
#  19%|█▉        | 1.85G/9.54G [02:03<07:54, 17.4MB/s]
#  19%|█▉        | 1.85G/9.54G [02:03<08:04, 17.0MB/s]
#  19%|█▉        | 1.85G/9.54G [02:03<07:49, 17.6MB/s]
#  19%|█▉        | 1.85G/9.54G [02:03<08:02, 17.1MB/s]
#  19%|█▉        | 1.85G/9.54G [02:04<07:45, 17.7MB/s]
#  19%|█▉        | 1.86G/9.54G [02:04<09:04, 15.2MB/s]
#  19%|█▉        | 1.86G/9.54G [02:04<08:21, 16.4MB/s]
#  19%|█▉        | 1.86G/9.54G [02:04<08:00, 17.2MB/s]
#  20%|█▉        | 1.86G/9.54G [02:04<08:10, 16.8MB/s]
#  20%|█▉        | 1.86G/9.54G [02:04<07:51, 17.5MB/s]
#  20%|█▉        | 1.87G/9.54G [02:04<09:08, 15.0MB/s]
#  20%|█▉        | 1.87G/9.54G [02:05<08:24, 16.3MB/s]
#  20%|█▉        | 1.87G/9.54G [02:05<08:02, 17.1MB/s]
#  20%|█▉        | 1.87G/9.54G [02:05<07:54, 17.3MB/s]
#  20%|█▉        | 1.88G/9.54G [02:05<07:57, 17.2MB/s]
#  20%|█▉        | 1.88G/9.54G [02:05<08:49, 15.5MB/s]
#  20%|█▉        | 1.88G/9.54G [02:05<07:57, 17.2MB/s]
#  20%|█▉        | 1.88G/9.54G [02:05<07:40, 17.9MB/s]
#  20%|█▉        | 1.88G/9.54G [02:06<07:40, 17.8MB/s]
#  20%|█▉        | 1.89G/9.54G [02:06<07:27, 18.4MB/s]
#  20%|█▉        | 1.89G/9.54G [02:06<08:31, 16.1MB/s]
#  20%|█▉        | 1.89G/9.54G [02:06<07:47, 17.6MB/s]
#  20%|█▉        | 1.89G/9.54G [02:06<07:33, 18.1MB/s]
#  20%|█▉        | 1.89G/9.54G [02:06<08:32, 16.0MB/s]
#  20%|█▉        | 1.90G/9.54G [02:06<07:48, 17.5MB/s]
#  20%|█▉        | 1.90G/9.54G [02:06<07:35, 18.0MB/s]
#  20%|█▉        | 1.90G/9.54G [02:07<07:36, 18.0MB/s]
#  20%|█▉        | 1.90G/9.54G [02:07<14:34, 9.38MB/s]
#  20%|█▉        | 1.91G/9.54G [02:07<12:40, 10.8MB/s]
#  20%|██        | 1.91G/9.54G [02:08<11:19, 12.1MB/s]
#  20%|██        | 1.91G/9.54G [02:08<09:39, 14.1MB/s]
#  20%|██        | 1.92G/9.54G [02:08<08:45, 15.6MB/s]
#  20%|██        | 1.92G/9.54G [02:08<08:46, 15.6MB/s]
#  20%|██        | 1.92G/9.54G [02:08<08:12, 16.6MB/s]
#  20%|██        | 1.93G/9.54G [02:09<07:53, 17.3MB/s]
#  20%|██        | 1.93G/9.54G [02:09<08:04, 16.9MB/s]
#  20%|██        | 1.93G/9.54G [02:09<07:48, 17.4MB/s]
#  20%|██        | 1.94G/9.54G [02:09<07:35, 17.9MB/s]
#  20%|██        | 1.94G/9.54G [02:09<07:51, 17.3MB/s]
#  20%|██        | 1.95G/9.54G [02:10<07:38, 17.8MB/s]
#  20%|██        | 1.95G/9.54G [02:10<07:54, 17.2MB/s]
#  20%|██        | 1.95G/9.54G [02:10<07:43, 17.6MB/s]
#  20%|██        | 1.96G/9.54G [02:10<07:34, 17.9MB/s]
#  21%|██        | 1.96G/9.54G [02:11<07:50, 17.3MB/s]
#  21%|██        | 1.96G/9.54G [02:11<07:58, 17.0MB/s]
#  21%|██        | 1.96G/9.54G [02:11<08:59, 15.1MB/s]
#  21%|██        | 1.97G/9.54G [02:11<08:19, 16.3MB/s]
#  21%|██        | 1.97G/9.54G [02:11<07:55, 17.1MB/s]
#  21%|██        | 1.98G/9.54G [02:12<08:07, 16.7MB/s]
#  21%|██        | 1.98G/9.54G [02:12<07:48, 17.3MB/s]
#  21%|██        | 1.98G/9.54G [02:12<07:35, 17.8MB/s]
#  21%|██        | 1.99G/9.54G [02:12<07:50, 17.3MB/s]
#  21%|██        | 1.99G/9.54G [02:13<07:37, 17.7MB/s]
#  21%|██        | 1.99G/9.54G [02:13<11:54, 11.3MB/s]
#  21%|██        | 2.00G/9.54G [02:13<10:24, 13.0MB/s]
#  21%|██        | 2.00G/9.54G [02:14<09:24, 14.3MB/s]
#  21%|██        | 2.00G/9.54G [02:14<09:15, 14.6MB/s]
#  21%|██        | 2.01G/9.54G [02:14<08:35, 15.7MB/s]
#  21%|██        | 2.01G/9.54G [02:14<08:06, 16.6MB/s]
#  21%|██        | 2.02G/9.54G [02:14<08:14, 16.3MB/s]
#  21%|██        | 2.02G/9.54G [02:15<07:53, 17.1MB/s]
#  21%|██        | 2.02G/9.54G [02:15<07:39, 17.6MB/s]
#  21%|██        | 2.03G/9.54G [02:15<07:56, 16.9MB/s]
#  21%|██▏       | 2.03G/9.54G [02:15<09:05, 14.8MB/s]
#  21%|██▏       | 2.03G/9.54G [02:16<08:27, 15.9MB/s]
#  21%|██▏       | 2.04G/9.54G [02:16<08:32, 15.7MB/s]
#  21%|██▏       | 2.04G/9.54G [02:16<08:03, 16.7MB/s]
#  21%|██▏       | 2.04G/9.54G [02:16<07:44, 17.3MB/s]
#  21%|██▏       | 2.05G/9.54G [02:16<07:57, 16.9MB/s]
#  21%|██▏       | 2.05G/9.54G [02:17<07:39, 17.5MB/s]
#  22%|██▏       | 2.05G/9.54G [02:17<07:55, 16.9MB/s]
#  22%|██▏       | 2.06G/9.54G [02:17<07:37, 17.6MB/s]
#  22%|██▏       | 2.06G/9.54G [02:17<07:25, 18.0MB/s]
#  22%|██▏       | 2.06G/9.54G [02:18<10:47, 12.4MB/s]
#  22%|██▏       | 2.07G/9.54G [02:18<09:37, 13.9MB/s]
#  22%|██▏       | 2.07G/9.54G [02:18<09:23, 14.3MB/s]
#  22%|██▏       | 2.07G/9.54G [02:18<08:35, 15.5MB/s]
#  22%|██▏       | 2.08G/9.54G [02:19<08:05, 16.5MB/s]
#  22%|██▏       | 2.08G/9.54G [02:19<08:14, 16.2MB/s]
#  22%|██▏       | 2.08G/9.54G [02:19<07:49, 17.0MB/s]
#  22%|██▏       | 2.09G/9.54G [02:19<07:34, 17.6MB/s]
#  22%|██▏       | 2.09G/9.54G [02:19<07:49, 17.0MB/s]
#  22%|██▏       | 2.10G/9.54G [02:20<07:33, 17.6MB/s]
#  22%|██▏       | 2.10G/9.54G [02:20<07:49, 17.0MB/s]
#  22%|██▏       | 2.10G/9.54G [02:20<07:32, 17.6MB/s]
#  22%|██▏       | 2.11G/9.54G [02:20<07:21, 18.1MB/s]
#  22%|██▏       | 2.11G/9.54G [02:21<07:40, 17.3MB/s]
#  22%|██▏       | 2.11G/9.54G [02:21<07:27, 17.8MB/s]
#  22%|██▏       | 2.12G/9.54G [02:21<07:18, 18.2MB/s]
#  22%|██▏       | 2.12G/9.54G [02:21<07:36, 17.5MB/s]
#  22%|██▏       | 2.12G/9.54G [02:21<07:25, 17.9MB/s]
#  22%|██▏       | 2.13G/9.54G [02:22<07:16, 18.2MB/s]
#  22%|██▏       | 2.13G/9.54G [02:22<07:34, 17.5MB/s]
#  22%|██▏       | 2.13G/9.54G [02:22<07:23, 17.9MB/s]
#  22%|██▏       | 2.14G/9.54G [02:22<07:15, 18.3MB/s]
#  22%|██▏       | 2.14G/9.54G [02:22<07:33, 17.5MB/s]
#  22%|██▏       | 2.15G/9.54G [02:23<07:22, 18.0MB/s]
#  23%|██▎       | 2.15G/9.54G [02:23<07:39, 17.3MB/s]
#  23%|██▎       | 2.15G/9.54G [02:23<07:25, 17.8MB/s]
#  23%|██▎       | 2.16G/9.54G [02:23<07:16, 18.2MB/s]
#  23%|██▎       | 2.16G/9.54G [02:24<07:36, 17.4MB/s]
#  23%|██▎       | 2.16G/9.54G [02:24<07:24, 17.8MB/s]
#  23%|██▎       | 2.17G/9.54G [02:24<07:15, 18.2MB/s]
#  23%|██▎       | 2.17G/9.54G [02:24<07:32, 17.5MB/s]
#  23%|██▎       | 2.17G/9.54G [02:24<07:21, 17.9MB/s]
#  23%|██▎       | 2.18G/9.54G [02:25<07:13, 18.3MB/s]
#  23%|██▎       | 2.18G/9.54G [02:25<07:50, 16.8MB/s]
#  23%|██▎       | 2.18G/9.54G [02:25<08:05, 16.3MB/s]
#  23%|██▎       | 2.19G/9.54G [02:25<07:41, 17.1MB/s]
#  23%|██▎       | 2.19G/9.54G [02:26<07:28, 17.6MB/s]
#  23%|██▎       | 2.19G/9.54G [02:26<07:45, 16.9MB/s]
#  23%|██▎       | 2.20G/9.54G [02:26<07:30, 17.5MB/s]
#  23%|██▎       | 2.20G/9.54G [02:26<07:36, 17.3MB/s]
#  23%|██▎       | 2.20G/9.54G [02:26<08:39, 15.2MB/s]
#  23%|██▎       | 2.21G/9.54G [02:27<08:04, 16.3MB/s]
#  23%|██▎       | 2.21G/9.54G [02:27<08:12, 16.0MB/s]
#  23%|██▎       | 2.21G/9.54G [02:27<07:47, 16.8MB/s]
#  23%|██▎       | 2.22G/9.54G [02:27<07:31, 17.4MB/s]
#  23%|██▎       | 2.22G/9.54G [02:27<07:45, 16.9MB/s]
#  23%|██▎       | 2.23G/9.54G [02:28<07:28, 17.5MB/s]
#  23%|██▎       | 2.23G/9.54G [02:28<07:16, 18.0MB/s]
#  23%|██▎       | 2.23G/9.54G [02:28<07:33, 17.3MB/s]
#  23%|██▎       | 2.24G/9.54G [02:28<07:22, 17.7MB/s]
#  23%|██▎       | 2.24G/9.54G [02:29<07:14, 18.0MB/s]
#  24%|██▎       | 2.24G/9.54G [02:29<07:33, 17.3MB/s]
#  24%|██▎       | 2.25G/9.54G [02:29<07:22, 17.7MB/s]
#  24%|██▎       | 2.25G/9.54G [02:29<07:14, 18.0MB/s]
#  24%|██▎       | 2.25G/9.54G [02:29<07:32, 17.3MB/s]
#  24%|██▎       | 2.26G/9.54G [02:30<07:19, 17.8MB/s]
#  24%|██▎       | 2.26G/9.54G [02:30<07:37, 17.1MB/s]
#  24%|██▎       | 2.26G/9.54G [02:30<07:24, 17.6MB/s]
#  24%|██▍       | 2.27G/9.54G [02:30<07:15, 17.9MB/s]
#  24%|██▍       | 2.27G/9.54G [02:31<07:32, 17.2MB/s]
#  24%|██▍       | 2.28G/9.54G [02:31<07:21, 17.7MB/s]
#  24%|██▍       | 2.28G/9.54G [02:31<07:12, 18.0MB/s]
#  24%|██▍       | 2.28G/9.54G [02:31<07:30, 17.3MB/s]
#  24%|██▍       | 2.29G/9.54G [02:31<07:20, 17.7MB/s]
#  24%|██▍       | 2.29G/9.54G [02:32<07:10, 18.1MB/s]
#  24%|██▍       | 2.29G/9.54G [02:32<07:26, 17.5MB/s]
#  24%|██▍       | 2.30G/9.54G [02:32<07:15, 17.9MB/s]
#  24%|██▍       | 2.30G/9.54G [02:32<07:32, 17.2MB/s]
#  24%|██▍       | 2.30G/9.54G [02:32<07:19, 17.7MB/s]
#  24%|██▍       | 2.31G/9.54G [02:33<07:13, 17.9MB/s]
#  24%|██▍       | 2.31G/9.54G [02:33<07:29, 17.3MB/s]
#  24%|██▍       | 2.31G/9.54G [02:33<07:19, 17.7MB/s]
#  24%|██▍       | 2.32G/9.54G [02:33<07:11, 18.0MB/s]
#  24%|██▍       | 2.32G/9.54G [02:34<07:28, 17.3MB/s]
#  24%|██▍       | 2.32G/9.54G [02:34<11:34, 11.2MB/s]
#  24%|██▍       | 2.33G/9.54G [02:34<09:56, 13.0MB/s]
#  24%|██▍       | 2.33G/9.54G [02:34<09:28, 13.6MB/s]
#  24%|██▍       | 2.33G/9.54G [02:35<08:33, 15.1MB/s]
#  24%|██▍       | 2.34G/9.54G [02:35<07:57, 16.2MB/s]
#  25%|██▍       | 2.34G/9.54G [02:35<08:02, 16.0MB/s]
#  25%|██▍       | 2.34G/9.54G [02:35<07:37, 16.9MB/s]
#  25%|██▍       | 2.35G/9.54G [02:35<07:47, 16.5MB/s]
#  25%|██▍       | 2.35G/9.54G [02:36<07:27, 17.3MB/s]
#  25%|██▍       | 2.36G/9.54G [02:36<07:13, 17.8MB/s]
#  25%|██▍       | 2.36G/9.54G [02:36<07:31, 17.1MB/s]
#  25%|██▍       | 2.36G/9.54G [02:36<07:18, 17.6MB/s]
#  25%|██▍       | 2.37G/9.54G [02:37<07:09, 17.9MB/s]
#  25%|██▍       | 2.37G/9.54G [02:37<07:27, 17.2MB/s]
#  25%|██▍       | 2.37G/9.54G [02:37<07:15, 17.7MB/s]
#  25%|██▍       | 2.38G/9.54G [02:37<07:07, 18.0MB/s]
#  25%|██▍       | 2.38G/9.54G [02:37<07:25, 17.3MB/s]
#  25%|██▍       | 2.38G/9.54G [02:38<07:14, 17.7MB/s]
#  25%|██▌       | 2.39G/9.54G [02:38<07:06, 18.0MB/s]
#  25%|██▌       | 2.39G/9.54G [02:38<07:24, 17.3MB/s]
#  25%|██▌       | 2.39G/9.54G [02:38<07:13, 17.7MB/s]
#  25%|██▌       | 2.40G/9.54G [02:39<07:05, 18.0MB/s]
#  25%|██▌       | 2.40G/9.54G [02:39<07:23, 17.3MB/s]
#  25%|██▌       | 2.41G/9.54G [02:39<07:12, 17.7MB/s]
#  25%|██▌       | 2.41G/9.54G [02:39<07:05, 18.0MB/s]
#  25%|██▌       | 2.41G/9.54G [02:39<07:23, 17.3MB/s]
#  25%|██▌       | 2.42G/9.54G [02:40<07:42, 16.6MB/s]
#  25%|██▌       | 2.42G/9.54G [02:40<07:23, 17.2MB/s]
#  25%|██▌       | 2.42G/9.54G [02:40<07:13, 17.6MB/s]
#  25%|██▌       | 2.42G/9.54G [02:40<08:18, 15.3MB/s]
#  25%|██▌       | 2.43G/9.54G [02:40<09:15, 13.8MB/s]
#  25%|██▌       | 2.43G/9.54G [02:41<08:18, 15.3MB/s]
#  26%|██▌       | 2.43G/9.54G [02:41<07:46, 16.4MB/s]
#  26%|██▌       | 2.44G/9.54G [02:41<07:26, 17.1MB/s]
#  26%|██▌       | 2.44G/9.54G [02:41<07:39, 16.6MB/s]
#  26%|██▌       | 2.45G/9.54G [02:42<07:31, 16.9MB/s]
#  26%|██▌       | 2.45G/9.54G [02:42<07:53, 16.1MB/s]
#  26%|██▌       | 2.45G/9.54G [02:42<07:40, 16.5MB/s]
#  26%|██▌       | 2.46G/9.54G [02:42<07:33, 16.8MB/s]
#  26%|██▌       | 2.46G/9.54G [02:43<07:51, 16.1MB/s]
#  26%|██▌       | 2.46G/9.54G [02:43<07:29, 16.9MB/s]
#  26%|██▌       | 2.47G/9.54G [02:43<11:25, 11.1MB/s]
#  26%|██▌       | 2.47G/9.54G [02:44<09:57, 12.7MB/s]
#  26%|██▌       | 2.47G/9.54G [02:44<09:05, 13.9MB/s]
#  26%|██▌       | 2.48G/9.54G [02:44<08:43, 14.5MB/s]
#  26%|██▌       | 2.48G/9.54G [02:44<08:14, 15.3MB/s]
#  26%|██▌       | 2.49G/9.54G [02:45<07:44, 16.3MB/s]
#  26%|██▌       | 2.49G/9.54G [02:45<07:42, 16.4MB/s]
#  26%|██▌       | 2.49G/9.54G [02:45<07:32, 16.7MB/s]
#  26%|██▌       | 2.50G/9.54G [02:45<07:16, 17.4MB/s]
#  26%|██▌       | 2.50G/9.54G [02:45<07:20, 17.2MB/s]
#  26%|██▌       | 2.50G/9.54G [02:46<07:17, 17.3MB/s]
#  26%|██▋       | 2.51G/9.54G [02:46<07:06, 17.7MB/s]
#  26%|██▋       | 2.51G/9.54G [02:46<07:12, 17.5MB/s]
#  26%|██▋       | 2.51G/9.54G [02:46<07:11, 17.5MB/s]
#  26%|██▋       | 2.52G/9.54G [02:46<07:03, 17.8MB/s]
#  26%|██▋       | 2.52G/9.54G [02:47<07:08, 17.6MB/s]
#  26%|██▋       | 2.52G/9.54G [02:47<07:09, 17.5MB/s]
#  26%|██▋       | 2.53G/9.54G [02:47<07:01, 17.9MB/s]
#  27%|██▋       | 2.53G/9.54G [02:47<07:07, 17.6MB/s]
#  27%|██▋       | 2.54G/9.54G [02:48<07:08, 17.6MB/s]
#  27%|██▋       | 2.54G/9.54G [02:48<06:59, 17.9MB/s]
#  27%|██▋       | 2.54G/9.54G [02:48<07:16, 17.2MB/s]
#  27%|██▋       | 2.55G/9.54G [02:48<07:23, 16.9MB/s]
#  27%|██▋       | 2.55G/9.54G [02:48<07:35, 16.5MB/s]
#  27%|██▋       | 2.55G/9.54G [02:49<07:25, 16.8MB/s]
#  27%|██▋       | 2.56G/9.54G [02:49<07:31, 16.6MB/s]
#  27%|██▋       | 2.56G/9.54G [02:49<07:38, 16.3MB/s]
#  27%|██▋       | 2.56G/9.54G [02:49<07:55, 15.7MB/s]
#  27%|██▋       | 2.57G/9.54G [02:50<08:13, 15.2MB/s]
#  27%|██▋       | 2.57G/9.54G [02:50<12:28, 10.0MB/s]
#  27%|██▋       | 2.57G/9.54G [02:50<10:35, 11.8MB/s]
#  27%|██▋       | 2.58G/9.54G [02:51<10:05, 12.4MB/s]
#  27%|██▋       | 2.58G/9.54G [02:51<09:02, 13.8MB/s]
#  27%|██▋       | 2.58G/9.54G [02:51<08:23, 14.8MB/s]
#  27%|██▋       | 2.59G/9.54G [02:51<08:28, 14.7MB/s]
#  27%|██▋       | 2.59G/9.54G [02:52<08:01, 15.5MB/s]
#  27%|██▋       | 2.59G/9.54G [02:52<07:42, 16.1MB/s]
#  27%|██▋       | 2.60G/9.54G [02:52<07:58, 15.6MB/s]
#  27%|██▋       | 2.60G/9.54G [02:52<07:41, 16.2MB/s]
#  27%|██▋       | 2.60G/9.54G [02:52<07:57, 15.6MB/s]
#  27%|██▋       | 2.61G/9.54G [02:53<07:30, 16.5MB/s]
#  27%|██▋       | 2.61G/9.54G [02:53<07:26, 16.7MB/s]
#  27%|██▋       | 2.61G/9.54G [02:53<08:22, 14.8MB/s]
#  27%|██▋       | 2.62G/9.54G [02:53<07:55, 15.7MB/s]
#  27%|██▋       | 2.62G/9.54G [02:54<08:08, 15.2MB/s]
#  27%|██▋       | 2.62G/9.54G [02:54<07:45, 16.0MB/s]
#  28%|██▊       | 2.63G/9.54G [02:54<07:32, 16.4MB/s]
#  28%|██▊       | 2.63G/9.54G [02:54<07:50, 15.8MB/s]
#  28%|██▊       | 2.63G/9.54G [02:55<07:25, 16.7MB/s]
#  28%|██▊       | 2.64G/9.54G [02:55<07:10, 17.2MB/s]
#  28%|██▊       | 2.64G/9.54G [02:55<07:22, 16.8MB/s]
#  28%|██▊       | 2.65G/9.54G [02:55<07:07, 17.3MB/s]
#  28%|██▊       | 2.65G/9.54G [02:55<06:56, 17.8MB/s]
#  28%|██▊       | 2.65G/9.54G [02:56<07:12, 17.1MB/s]
#  28%|██▊       | 2.66G/9.54G [02:56<07:00, 17.6MB/s]
#  28%|██▊       | 2.66G/9.54G [02:56<06:51, 18.0MB/s]
#  28%|██▊       | 2.66G/9.54G [02:56<07:08, 17.2MB/s]
#  28%|██▊       | 2.67G/9.54G [02:57<06:57, 17.7MB/s]
#  28%|██▊       | 2.67G/9.54G [02:57<07:23, 16.7MB/s]
#  28%|██▊       | 2.67G/9.54G [02:57<07:16, 16.9MB/s]
#  28%|██▊       | 2.68G/9.54G [02:57<07:11, 17.1MB/s]
#  28%|██▊       | 2.68G/9.54G [02:57<07:33, 16.3MB/s]
#  28%|██▊       | 2.68G/9.54G [02:58<07:22, 16.6MB/s]
#  28%|██▊       | 2.69G/9.54G [02:58<07:15, 16.9MB/s]
#  28%|██▊       | 2.69G/9.54G [02:58<07:35, 16.1MB/s]
#  28%|██▊       | 2.70G/9.54G [02:58<08:04, 15.2MB/s]
#  28%|██▊       | 2.70G/9.54G [02:59<08:32, 14.3MB/s]
#  28%|██▊       | 2.70G/9.54G [02:59<07:59, 15.3MB/s]
#  28%|██▊       | 2.70G/9.54G [02:59<08:09, 15.0MB/s]
#  28%|██▊       | 2.71G/9.54G [02:59<07:45, 15.8MB/s]
#  28%|██▊       | 2.71G/9.54G [03:00<07:30, 16.3MB/s]
#  28%|██▊       | 2.71G/9.54G [03:00<07:46, 15.7MB/s]
#  28%|██▊       | 2.72G/9.54G [03:00<07:30, 16.3MB/s]
#  29%|██▊       | 2.72G/9.54G [03:00<07:37, 16.0MB/s]
#  29%|██▊       | 2.72G/9.54G [03:01<10:47, 11.3MB/s]
#  29%|██▊       | 2.73G/9.54G [03:01<09:17, 13.1MB/s]
#  29%|██▊       | 2.73G/9.54G [03:01<08:22, 14.6MB/s]
#  29%|██▊       | 2.74G/9.54G [03:01<07:45, 15.7MB/s]
#  29%|██▊       | 2.74G/9.54G [03:02<07:58, 15.3MB/s]
#  29%|██▊       | 2.74G/9.54G [03:02<07:38, 15.9MB/s]
#  29%|██▉       | 2.75G/9.54G [03:02<07:24, 16.4MB/s]
#  29%|██▉       | 2.75G/9.54G [03:02<07:41, 15.8MB/s]
#  29%|██▉       | 2.75G/9.54G [03:03<07:26, 16.3MB/s]
#  29%|██▉       | 2.76G/9.54G [03:03<07:43, 15.7MB/s]
#  29%|██▉       | 2.76G/9.54G [03:03<07:27, 16.3MB/s]
#  29%|██▉       | 2.76G/9.54G [03:03<07:16, 16.7MB/s]
#  29%|██▉       | 2.77G/9.54G [03:03<07:35, 16.0MB/s]
#  29%|██▉       | 2.77G/9.54G [03:04<07:21, 16.5MB/s]
#  29%|██▉       | 2.78G/9.54G [03:04<07:13, 16.8MB/s]
#  29%|██▉       | 2.78G/9.54G [03:04<07:32, 16.0MB/s]
#  29%|██▉       | 2.78G/9.54G [03:04<07:19, 16.5MB/s]
#  29%|██▉       | 2.79G/9.54G [03:05<07:12, 16.8MB/s]
#  29%|██▉       | 2.79G/9.54G [03:05<07:31, 16.1MB/s]
#  29%|██▉       | 2.79G/9.54G [03:05<07:18, 16.5MB/s]
#  29%|██▉       | 2.80G/9.54G [03:05<07:10, 16.8MB/s]
#  29%|██▉       | 2.80G/9.54G [03:06<07:47, 15.5MB/s]
#  29%|██▉       | 2.80G/9.54G [03:06<08:48, 13.7MB/s]
#  29%|██▉       | 2.81G/9.54G [03:06<08:11, 14.7MB/s]
#  29%|██▉       | 2.81G/9.54G [03:06<08:16, 14.6MB/s]
#  29%|██▉       | 2.81G/9.54G [03:07<07:47, 15.4MB/s]
#  30%|██▉       | 2.82G/9.54G [03:07<07:28, 16.1MB/s]
#  30%|██▉       | 2.82G/9.54G [03:07<07:44, 15.6MB/s]
#  30%|██▉       | 2.82G/9.54G [03:07<07:27, 16.1MB/s]
#  30%|██▉       | 2.83G/9.54G [03:07<07:15, 16.6MB/s]
#  30%|██▉       | 2.83G/9.54G [03:08<07:32, 15.9MB/s]
#  30%|██▉       | 2.83G/9.54G [03:08<07:20, 16.4MB/s]
#  30%|██▉       | 2.84G/9.54G [03:08<07:10, 16.7MB/s]
#  30%|██▉       | 2.84G/9.54G [03:08<07:28, 16.1MB/s]
#  30%|██▉       | 2.84G/9.54G [03:09<07:17, 16.5MB/s]
#  30%|██▉       | 2.85G/9.54G [03:09<07:08, 16.8MB/s]
#  30%|██▉       | 2.85G/9.54G [03:09<07:25, 16.1MB/s]
#  30%|██▉       | 2.86G/9.54G [03:09<07:15, 16.5MB/s]
#  30%|██▉       | 2.86G/9.54G [03:10<07:07, 16.8MB/s]
#  30%|██▉       | 2.86G/9.54G [03:10<07:24, 16.1MB/s]
#  30%|███       | 2.87G/9.54G [03:10<07:14, 16.5MB/s]
#  30%|███       | 2.87G/9.54G [03:10<07:30, 15.9MB/s]
#  30%|███       | 2.87G/9.54G [03:10<07:16, 16.4MB/s]
#  30%|███       | 2.88G/9.54G [03:11<07:08, 16.7MB/s]
#  30%|███       | 2.88G/9.54G [03:11<07:26, 16.0MB/s]
#  30%|███       | 2.88G/9.54G [03:11<07:27, 16.0MB/s]
#  30%|███       | 2.89G/9.54G [03:11<07:45, 15.4MB/s]
#  30%|███       | 2.89G/9.54G [03:12<07:26, 16.0MB/s]
#  30%|███       | 2.89G/9.54G [03:12<07:13, 16.5MB/s]
#  30%|███       | 2.90G/9.54G [03:12<07:30, 15.8MB/s]
#  30%|███       | 2.90G/9.54G [03:12<07:15, 16.4MB/s]
#  30%|███       | 2.91G/9.54G [03:13<07:06, 16.7MB/s]
#  30%|███       | 2.91G/9.54G [03:13<07:25, 16.0MB/s]
#  31%|███       | 2.91G/9.54G [03:13<07:12, 16.5MB/s]
#  31%|███       | 2.92G/9.54G [03:13<07:31, 15.8MB/s]
#  31%|███       | 2.92G/9.54G [03:14<07:15, 16.3MB/s]
#  31%|███       | 2.92G/9.54G [03:14<07:05, 16.7MB/s]
# ...
#  89%|████████▉ | 8.49G/9.54G [09:12<01:09, 16.2MB/s]
#  89%|████████▉ | 8.50G/9.54G [09:13<01:11, 15.6MB/s]
#  89%|████████▉ | 8.50G/9.54G [09:13<01:09, 16.2MB/s]
#  89%|████████▉ | 8.50G/9.54G [09:13<01:11, 15.6MB/s]
#  89%|████████▉ | 8.51G/9.54G [09:13<01:08, 16.2MB/s]
#  89%|████████▉ | 8.51G/9.54G [09:14<01:05, 16.9MB/s]
#  89%|████████▉ | 8.51G/9.54G [09:14<01:06, 16.5MB/s]
#  89%|████████▉ | 8.52G/9.54G [09:14<01:04, 17.1MB/s]
#  89%|████████▉ | 8.52G/9.54G [09:14<01:02, 17.6MB/s]
#  89%|████████▉ | 8.53G/9.54G [09:14<01:04, 16.9MB/s]
#  89%|████████▉ | 8.53G/9.54G [09:15<01:02, 17.5MB/s]
#  89%|████████▉ | 8.53G/9.54G [09:15<01:00, 17.8MB/s]
#  89%|████████▉ | 8.54G/9.54G [09:15<01:02, 17.2MB/s]
#  89%|████████▉ | 8.54G/9.54G [09:15<01:01, 17.6MB/s]
#  90%|████████▉ | 8.54G/9.54G [09:16<00:59, 17.9MB/s]
#  90%|████████▉ | 8.55G/9.54G [09:16<01:02, 17.2MB/s]
#  90%|████████▉ | 8.55G/9.54G [09:16<01:00, 17.6MB/s]
#  90%|████████▉ | 8.55G/9.54G [09:16<01:32, 11.4MB/s]
#  90%|████████▉ | 8.56G/9.54G [09:17<01:27, 12.1MB/s]
#  90%|████████▉ | 8.56G/9.54G [09:17<01:16, 13.9MB/s]
#  90%|████████▉ | 8.56G/9.54G [09:17<01:15, 14.0MB/s]
#  90%|████████▉ | 8.57G/9.54G [09:17<01:09, 15.0MB/s]
#  90%|████████▉ | 8.57G/9.54G [09:18<01:06, 15.8MB/s]
#  90%|████████▉ | 8.57G/9.54G [09:18<01:07, 15.3MB/s]
#  90%|████████▉ | 8.58G/9.54G [09:18<01:04, 16.0MB/s]
#  90%|████████▉ | 8.58G/9.54G [09:18<01:02, 16.4MB/s]
#  90%|████████▉ | 8.58G/9.54G [09:18<01:04, 15.9MB/s]
#  90%|████████▉ | 8.59G/9.54G [09:19<01:02, 16.4MB/s]
#  90%|█████████ | 8.59G/9.54G [09:19<01:01, 16.7MB/s]
#  90%|█████████ | 8.59G/9.54G [09:19<01:35, 10.7MB/s]
#  90%|█████████ | 8.60G/9.54G [09:20<01:22, 12.3MB/s]
#  90%|█████████ | 8.60G/9.54G [09:20<01:19, 12.7MB/s]
#  90%|█████████ | 8.60G/9.54G [09:20<01:11, 14.1MB/s]
#  90%|█████████ | 8.61G/9.54G [09:20<01:08, 14.7MB/s]
#  90%|█████████ | 8.61G/9.54G [09:21<01:09, 14.5MB/s]
#  90%|█████████ | 8.62G/9.54G [09:21<01:06, 14.9MB/s]
#  90%|█████████ | 8.62G/9.54G [09:21<01:14, 13.4MB/s]
#  90%|█████████ | 8.62G/9.54G [09:21<01:07, 14.6MB/s]
#  90%|█████████ | 8.62G/9.54G [09:22<01:08, 14.5MB/s]
#  90%|█████████ | 8.63G/9.54G [09:22<01:03, 15.4MB/s]
#  90%|█████████ | 8.63G/9.54G [09:22<01:00, 16.1MB/s]
#  90%|█████████ | 8.63G/9.54G [09:22<01:01, 15.8MB/s]
#  91%|█████████ | 8.64G/9.54G [09:23<00:58, 16.7MB/s]
#  91%|█████████ | 8.64G/9.54G [09:23<00:55, 17.3MB/s]
#  91%|█████████ | 8.65G/9.54G [09:23<00:57, 16.7MB/s]
#  91%|█████████ | 8.65G/9.54G [09:24<01:28, 10.8MB/s]
#  91%|█████████ | 8.65G/9.54G [09:24<01:16, 12.5MB/s]
#  91%|█████████ | 8.66G/9.54G [09:24<01:08, 14.0MB/s]
#  91%|█████████ | 8.66G/9.54G [09:24<01:06, 14.3MB/s]
#  91%|█████████ | 8.66G/9.54G [09:25<01:31, 10.3MB/s]
#  91%|█████████ | 8.67G/9.54G [09:25<01:18, 12.0MB/s]
#  91%|█████████ | 8.67G/9.54G [09:25<01:09, 13.5MB/s]
#  91%|█████████ | 8.67G/9.54G [09:26<01:06, 14.0MB/s]
#  91%|█████████ | 8.68G/9.54G [09:26<01:00, 15.2MB/s]
#  91%|█████████ | 8.68G/9.54G [09:26<00:56, 16.3MB/s]
#  91%|█████████ | 8.69G/9.54G [09:26<00:57, 16.0MB/s]
#  91%|█████████ | 8.69G/9.54G [09:26<00:54, 16.9MB/s]
#  91%|█████████ | 8.69G/9.54G [09:27<00:55, 16.5MB/s]
#  91%|█████████ | 8.70G/9.54G [09:27<00:52, 17.2MB/s]
#  91%|█████████ | 8.70G/9.54G [09:27<00:51, 17.7MB/s]
#  91%|█████████ | 8.70G/9.54G [09:27<00:52, 17.1MB/s]
#  91%|█████████ | 8.71G/9.54G [09:28<00:50, 17.6MB/s]
#  91%|█████████▏| 8.71G/9.54G [09:28<00:49, 18.1MB/s]
#  91%|█████████▏| 8.71G/9.54G [09:28<00:51, 17.3MB/s]
#  91%|█████████▏| 8.72G/9.54G [09:28<00:49, 17.8MB/s]
#  91%|█████████▏| 8.72G/9.54G [09:28<00:48, 18.1MB/s]
#  91%|█████████▏| 8.72G/9.54G [09:29<00:50, 17.3MB/s]
#  91%|█████████▏| 8.73G/9.54G [09:29<00:49, 17.8MB/s]
#  92%|█████████▏| 8.73G/9.54G [09:29<00:47, 18.2MB/s]
#  92%|█████████▏| 8.73G/9.54G [09:29<00:55, 15.7MB/s]
#  92%|█████████▏| 8.74G/9.54G [09:29<01:01, 14.1MB/s]
#  92%|█████████▏| 8.74G/9.54G [09:30<00:55, 15.6MB/s]
#  92%|█████████▏| 8.74G/9.54G [09:30<00:55, 15.5MB/s]
#  92%|█████████▏| 8.75G/9.54G [09:30<00:51, 16.6MB/s]
#  92%|█████████▏| 8.75G/9.54G [09:30<00:49, 17.3MB/s]
#  92%|█████████▏| 8.75G/9.54G [09:31<00:50, 16.8MB/s]
#  92%|█████████▏| 8.76G/9.54G [09:31<00:48, 17.4MB/s]
#  92%|█████████▏| 8.76G/9.54G [09:31<00:46, 17.9MB/s]
#  92%|█████████▏| 8.76G/9.54G [09:31<00:50, 16.5MB/s]
#  92%|█████████▏| 8.77G/9.54G [09:31<00:48, 17.1MB/s]
#  92%|█████████▏| 8.77G/9.54G [09:32<00:49, 16.6MB/s]
#  92%|█████████▏| 8.78G/9.54G [09:32<00:47, 17.3MB/s]
#  92%|█████████▏| 8.78G/9.54G [09:32<00:48, 16.8MB/s]
#  92%|█████████▏| 8.78G/9.54G [09:32<00:46, 17.4MB/s]
#  92%|█████████▏| 8.79G/9.54G [09:33<00:45, 17.9MB/s]
#  92%|█████████▏| 8.79G/9.54G [09:33<00:47, 17.2MB/s]
#  92%|█████████▏| 8.79G/9.54G [09:33<00:45, 17.7MB/s]
#  92%|█████████▏| 8.80G/9.54G [09:33<00:44, 18.1MB/s]
#  92%|█████████▏| 8.80G/9.54G [09:33<00:46, 17.3MB/s]
#  92%|█████████▏| 8.80G/9.54G [09:34<00:44, 17.8MB/s]
#  92%|█████████▏| 8.81G/9.54G [09:34<00:43, 18.2MB/s]
#  92%|█████████▏| 8.81G/9.54G [09:34<00:46, 17.0MB/s]
#  92%|█████████▏| 8.81G/9.54G [09:34<00:45, 17.1MB/s]
#  92%|█████████▏| 8.82G/9.54G [09:35<00:46, 16.7MB/s]
#  92%|█████████▏| 8.82G/9.54G [09:35<00:53, 14.5MB/s]
#  92%|█████████▏| 8.82G/9.54G [09:35<00:49, 15.4MB/s]
#  92%|█████████▏| 8.83G/9.54G [09:35<00:48, 16.0MB/s]
#  93%|█████████▎| 8.83G/9.54G [09:35<00:49, 15.6MB/s]
#  93%|█████████▎| 8.83G/9.54G [09:36<00:46, 16.2MB/s]
#  93%|█████████▎| 8.84G/9.54G [09:36<00:45, 16.5MB/s]
#  93%|█████████▎| 8.84G/9.54G [09:36<00:47, 15.9MB/s]
#  93%|█████████▎| 8.84G/9.54G [09:36<00:46, 16.3MB/s]
#  93%|█████████▎| 8.85G/9.54G [09:37<00:48, 15.3MB/s]
#  93%|█████████▎| 8.85G/9.54G [09:37<00:49, 14.9MB/s]
#  93%|█████████▎| 8.86G/9.54G [09:37<00:47, 15.6MB/s]
#  93%|█████████▎| 8.86G/9.54G [09:37<00:45, 16.3MB/s]
#  93%|█████████▎| 8.86G/9.54G [09:38<00:46, 15.7MB/s]
#  93%|█████████▎| 8.87G/9.54G [09:38<00:44, 16.2MB/s]
#  93%|█████████▎| 8.87G/9.54G [09:38<00:46, 15.6MB/s]
#  93%|█████████▎| 8.87G/9.54G [09:38<00:44, 16.2MB/s]
#  93%|█████████▎| 8.88G/9.54G [09:39<00:42, 16.8MB/s]
#  93%|█████████▎| 8.88G/9.54G [09:39<00:43, 16.2MB/s]
#  93%|█████████▎| 8.88G/9.54G [09:39<00:41, 17.0MB/s]
#  93%|█████████▎| 8.89G/9.54G [09:39<00:40, 17.5MB/s]
#  93%|█████████▎| 8.89G/9.54G [09:39<00:41, 16.9MB/s]
#  93%|█████████▎| 8.89G/9.54G [09:40<00:39, 17.4MB/s]
#  93%|█████████▎| 8.90G/9.54G [09:40<00:38, 17.8MB/s]
#  93%|█████████▎| 8.90G/9.54G [09:40<00:40, 17.1MB/s]
#  93%|█████████▎| 8.91G/9.54G [09:40<00:38, 17.6MB/s]
#  93%|█████████▎| 8.91G/9.54G [09:40<00:37, 17.9MB/s]
#  93%|█████████▎| 8.91G/9.54G [09:41<00:39, 17.2MB/s]
#  93%|█████████▎| 8.92G/9.54G [09:41<00:38, 17.6MB/s]
#  93%|█████████▎| 8.92G/9.54G [09:41<00:39, 16.9MB/s]
#  94%|█████████▎| 8.92G/9.54G [09:41<00:38, 17.5MB/s]
#  94%|█████████▎| 8.93G/9.54G [09:42<00:37, 17.9MB/s]
#  94%|█████████▎| 8.93G/9.54G [09:42<00:38, 17.1MB/s]
#  94%|█████████▎| 8.93G/9.54G [09:42<00:37, 17.6MB/s]
#  94%|█████████▎| 8.94G/9.54G [09:42<00:36, 17.9MB/s]
#  94%|█████████▎| 8.94G/9.54G [09:42<00:37, 17.2MB/s]
#  94%|█████████▎| 8.94G/9.54G [09:43<00:36, 17.6MB/s]
#  94%|█████████▍| 8.95G/9.54G [09:43<00:35, 18.0MB/s]
#  94%|█████████▍| 8.95G/9.54G [09:43<00:36, 17.2MB/s]
#  94%|█████████▍| 8.96G/9.54G [09:43<00:35, 17.7MB/s]
#  94%|█████████▍| 8.96G/9.54G [09:44<00:34, 17.9MB/s]
#  94%|█████████▍| 8.96G/9.54G [09:44<00:36, 17.2MB/s]
#  94%|█████████▍| 8.97G/9.54G [09:44<00:35, 17.7MB/s]
#  94%|█████████▍| 8.97G/9.54G [09:44<00:34, 17.9MB/s]
#  94%|█████████▍| 8.97G/9.54G [09:44<00:35, 17.2MB/s]
#  94%|█████████▍| 8.98G/9.54G [09:45<00:34, 17.7MB/s]
#  94%|█████████▍| 8.98G/9.54G [09:45<00:33, 17.9MB/s]
#  94%|█████████▍| 8.98G/9.54G [09:45<00:34, 17.2MB/s]
#  94%|█████████▍| 8.99G/9.54G [09:45<00:33, 17.7MB/s]
#  94%|█████████▍| 8.99G/9.54G [09:45<00:32, 18.0MB/s]
#  94%|█████████▍| 8.99G/9.54G [09:46<00:34, 17.3MB/s]
#  94%|█████████▍| 9.00G/9.54G [09:46<00:33, 17.7MB/s]
#  94%|█████████▍| 9.00G/9.54G [09:46<00:34, 17.0MB/s]
#  94%|█████████▍| 9.00G/9.54G [09:47<00:52, 10.9MB/s]
#  94%|█████████▍| 9.01G/9.54G [09:47<00:45, 12.6MB/s]
#  94%|█████████▍| 9.01G/9.54G [09:47<00:43, 13.2MB/s]
#  94%|█████████▍| 9.02G/9.54G [09:47<00:38, 14.6MB/s]
#  95%|█████████▍| 9.02G/9.54G [09:48<00:35, 15.7MB/s]
#  95%|█████████▍| 9.02G/9.54G [09:48<00:35, 15.6MB/s]
#  95%|█████████▍| 9.03G/9.54G [09:48<00:33, 16.6MB/s]
#  95%|█████████▍| 9.03G/9.54G [09:48<00:31, 17.3MB/s]
#  95%|█████████▍| 9.03G/9.54G [09:49<00:32, 16.7MB/s]
#  95%|█████████▍| 9.04G/9.54G [09:49<00:31, 17.4MB/s]
#  95%|█████████▍| 9.04G/9.54G [09:49<00:30, 17.9MB/s]
#  95%|█████████▍| 9.04G/9.54G [09:49<00:31, 17.2MB/s]
#  95%|█████████▍| 9.05G/9.54G [09:49<00:30, 17.7MB/s]
#  95%|█████████▍| 9.05G/9.54G [09:50<00:31, 17.0MB/s]
#  95%|█████████▍| 9.05G/9.54G [09:50<00:29, 17.6MB/s]
#  95%|█████████▍| 9.06G/9.54G [09:50<00:28, 18.0MB/s]
#  95%|█████████▍| 9.06G/9.54G [09:50<00:29, 17.3MB/s]
#  95%|█████████▍| 9.07G/9.54G [09:50<00:28, 17.8MB/s]
#  95%|█████████▌| 9.07G/9.54G [09:51<00:28, 18.1MB/s]
#  95%|█████████▌| 9.07G/9.54G [09:51<00:29, 17.4MB/s]
#  95%|█████████▌| 9.08G/9.54G [09:51<00:28, 17.8MB/s]
#  95%|█████████▌| 9.08G/9.54G [09:51<00:27, 18.2MB/s]
#  95%|█████████▌| 9.08G/9.54G [09:52<00:28, 17.4MB/s]
#  95%|█████████▌| 9.09G/9.54G [09:52<00:27, 17.9MB/s]
#  95%|█████████▌| 9.09G/9.54G [09:52<00:26, 18.2MB/s]
#  95%|█████████▌| 9.09G/9.54G [09:52<00:27, 17.4MB/s]
#  95%|█████████▌| 9.10G/9.54G [09:52<00:26, 17.8MB/s]
#  95%|█████████▌| 9.10G/9.54G [09:53<00:27, 17.2MB/s]
#  95%|█████████▌| 9.10G/9.54G [09:53<00:26, 17.7MB/s]
#  95%|█████████▌| 9.11G/9.54G [09:53<00:25, 18.1MB/s]
#  95%|█████████▌| 9.11G/9.54G [09:53<00:26, 17.3MB/s]
#  96%|█████████▌| 9.12G/9.54G [09:53<00:25, 17.8MB/s]
#  96%|█████████▌| 9.12G/9.54G [09:54<00:25, 18.1MB/s]
#  96%|█████████▌| 9.12G/9.54G [09:54<00:25, 17.4MB/s]
#  96%|█████████▌| 9.13G/9.54G [09:54<00:25, 17.4MB/s]
#  96%|█████████▌| 9.13G/9.54G [09:54<00:25, 17.4MB/s]
#  96%|█████████▌| 9.13G/9.54G [09:55<00:26, 16.5MB/s]
#  96%|█████████▌| 9.14G/9.54G [09:55<00:25, 16.8MB/s]
#  96%|█████████▌| 9.14G/9.54G [09:55<00:25, 17.0MB/s]
#  96%|█████████▌| 9.14G/9.54G [09:55<00:26, 16.2MB/s]
#  96%|█████████▌| 9.15G/9.54G [09:56<00:25, 16.6MB/s]
#  96%|█████████▌| 9.15G/9.54G [09:56<00:26, 15.9MB/s]
#  96%|█████████▌| 9.15G/9.54G [09:56<00:25, 16.4MB/s]
#  96%|█████████▌| 9.16G/9.54G [09:56<00:24, 16.7MB/s]
#  96%|█████████▌| 9.16G/9.54G [09:56<00:25, 16.0MB/s]
#  96%|█████████▌| 9.17G/9.54G [09:57<00:24, 16.8MB/s]
#  96%|█████████▌| 9.17G/9.54G [09:57<00:23, 17.4MB/s]
#  96%|█████████▌| 9.17G/9.54G [09:57<00:23, 16.9MB/s]
#  96%|█████████▌| 9.18G/9.54G [09:57<00:22, 17.5MB/s]
#  96%|█████████▌| 9.18G/9.54G [09:58<00:21, 17.9MB/s]
#  96%|█████████▌| 9.18G/9.54G [09:58<00:22, 17.2MB/s]
#  96%|█████████▋| 9.19G/9.54G [09:58<00:21, 17.7MB/s]
#  96%|█████████▋| 9.19G/9.54G [09:58<00:20, 18.1MB/s]
#  96%|█████████▋| 9.19G/9.54G [09:58<00:21, 17.3MB/s]
#  96%|█████████▋| 9.20G/9.54G [09:59<00:20, 17.8MB/s]
#  96%|█████████▋| 9.20G/9.54G [09:59<00:20, 18.1MB/s]
#  96%|█████████▋| 9.20G/9.54G [09:59<00:20, 17.4MB/s]
#  96%|█████████▋| 9.21G/9.54G [09:59<00:20, 17.9MB/s]
#  97%|█████████▋| 9.21G/9.54G [10:00<00:19, 18.1MB/s]
#  97%|█████████▋| 9.21G/9.54G [10:00<00:20, 17.4MB/s]
#  97%|█████████▋| 9.22G/9.54G [10:00<00:19, 17.9MB/s]
#  97%|█████████▋| 9.22G/9.54G [10:00<00:18, 18.2MB/s]
#  97%|█████████▋| 9.23G/9.54G [10:00<00:19, 17.4MB/s]
#  97%|█████████▋| 9.23G/9.54G [10:01<00:18, 17.9MB/s]
#  97%|█████████▋| 9.23G/9.54G [10:01<00:19, 17.2MB/s]
#  97%|█████████▋| 9.24G/9.54G [10:01<00:18, 17.7MB/s]
#  97%|█████████▋| 9.24G/9.54G [10:01<00:17, 18.1MB/s]
#  97%|█████████▋| 9.24G/9.54G [10:01<00:18, 17.3MB/s]
#  97%|█████████▋| 9.25G/9.54G [10:02<00:17, 17.8MB/s]
#  97%|█████████▋| 9.25G/9.54G [10:02<00:17, 18.1MB/s]
#  97%|█████████▋| 9.25G/9.54G [10:02<00:17, 17.4MB/s]
#  97%|█████████▋| 9.26G/9.54G [10:02<00:17, 17.8MB/s]
#  97%|█████████▋| 9.26G/9.54G [10:03<00:17, 17.4MB/s]
#  97%|█████████▋| 9.26G/9.54G [10:03<00:19, 15.4MB/s]
#  97%|█████████▋| 9.27G/9.54G [10:03<00:17, 16.4MB/s]
#  97%|█████████▋| 9.27G/9.54G [10:03<00:18, 16.1MB/s]
#  97%|█████████▋| 9.27G/9.54G [10:03<00:16, 17.0MB/s]
#  97%|█████████▋| 9.28G/9.54G [10:04<00:16, 17.6MB/s]
#  97%|█████████▋| 9.28G/9.54G [10:04<00:16, 17.0MB/s]
#  97%|█████████▋| 9.29G/9.54G [10:04<00:15, 17.6MB/s]
#  97%|█████████▋| 9.29G/9.54G [10:04<00:15, 18.0MB/s]
#  97%|█████████▋| 9.29G/9.54G [10:04<00:15, 17.2MB/s]
#  97%|█████████▋| 9.30G/9.54G [10:05<00:15, 17.3MB/s]
#  97%|█████████▋| 9.30G/9.54G [10:05<00:14, 17.4MB/s]
#  97%|█████████▋| 9.30G/9.54G [10:05<00:15, 16.5MB/s]
#  98%|█████████▊| 9.31G/9.54G [10:05<00:15, 16.8MB/s]
#  98%|█████████▊| 9.31G/9.54G [10:06<00:15, 16.4MB/s]
#  98%|█████████▊| 9.31G/9.54G [10:06<00:14, 17.2MB/s]
#  98%|█████████▊| 9.32G/9.54G [10:06<00:13, 17.7MB/s]
#  98%|█████████▊| 9.32G/9.54G [10:06<00:14, 17.0MB/s]
#  98%|█████████▊| 9.32G/9.54G [10:06<00:13, 17.6MB/s]
#  98%|█████████▊| 9.33G/9.54G [10:07<00:12, 18.0MB/s]
#  98%|█████████▊| 9.33G/9.54G [10:07<00:13, 17.3MB/s]
#  98%|█████████▊| 9.33G/9.54G [10:07<00:13, 17.1MB/s]
#  98%|█████████▊| 9.34G/9.54G [10:07<00:13, 16.5MB/s]
#  98%|█████████▊| 9.34G/9.54G [10:08<00:12, 17.2MB/s]
#  98%|█████████▊| 9.35G/9.54G [10:08<00:11, 17.7MB/s]
#  98%|█████████▊| 9.35G/9.54G [10:08<00:12, 17.1MB/s]
#  98%|█████████▊| 9.35G/9.54G [10:08<00:11, 17.6MB/s]
#  98%|█████████▊| 9.36G/9.54G [10:08<00:11, 18.0MB/s]
#  98%|█████████▊| 9.36G/9.54G [10:09<00:11, 17.3MB/s]
#  98%|█████████▊| 9.36G/9.54G [10:09<00:10, 17.8MB/s]
#  98%|█████████▊| 9.37G/9.54G [10:09<00:10, 18.1MB/s]
#  98%|█████████▊| 9.37G/9.54G [10:09<00:10, 17.4MB/s]
#  98%|█████████▊| 9.37G/9.54G [10:10<00:10, 17.8MB/s]
#  98%|█████████▊| 9.38G/9.54G [10:10<00:10, 16.5MB/s]
#  98%|█████████▊| 9.38G/9.54G [10:10<00:11, 15.7MB/s]
#  98%|█████████▊| 9.38G/9.54G [10:10<00:10, 16.7MB/s]
#  98%|█████████▊| 9.39G/9.54G [10:10<00:10, 16.3MB/s]
#  98%|█████████▊| 9.39G/9.54G [10:11<00:09, 17.1MB/s]
#  98%|█████████▊| 9.39G/9.54G [10:11<00:09, 16.6MB/s]
#  98%|█████████▊| 9.40G/9.54G [10:11<00:09, 17.3MB/s]
#  99%|█████████▊| 9.40G/9.54G [10:11<00:08, 17.8MB/s]
#  99%|█████████▊| 9.40G/9.54G [10:11<00:08, 17.1MB/s]
#  99%|█████████▊| 9.41G/9.54G [10:12<00:08, 17.7MB/s]
#  99%|█████████▊| 9.41G/9.54G [10:12<00:07, 18.1MB/s]
#  99%|█████████▊| 9.42G/9.54G [10:12<00:07, 17.3MB/s]
#  99%|█████████▊| 9.42G/9.54G [10:12<00:07, 17.8MB/s]
#  99%|█████████▊| 9.42G/9.54G [10:13<00:07, 18.1MB/s]
#  99%|█████████▉| 9.43G/9.54G [10:13<00:07, 17.4MB/s]
#  99%|█████████▉| 9.43G/9.54G [10:13<00:06, 17.8MB/s]
#  99%|█████████▉| 9.43G/9.54G [10:13<00:06, 18.1MB/s]
#  99%|█████████▉| 9.44G/9.54G [10:13<00:06, 17.4MB/s]
#  99%|█████████▉| 9.44G/9.54G [10:14<00:06, 17.9MB/s]
#  99%|█████████▉| 9.44G/9.54G [10:14<00:05, 18.2MB/s]
#  99%|█████████▉| 9.45G/9.54G [10:14<00:06, 16.7MB/s]
#  99%|█████████▉| 9.45G/9.54G [10:14<00:06, 16.2MB/s]
#  99%|█████████▉| 9.45G/9.54G [10:15<00:05, 17.0MB/s]
#  99%|█████████▉| 9.46G/9.54G [10:15<00:05, 16.6MB/s]
#  99%|█████████▉| 9.46G/9.54G [10:15<00:05, 17.3MB/s]
#  99%|█████████▉| 9.46G/9.54G [10:15<00:04, 17.8MB/s]
#  99%|█████████▉| 9.47G/9.54G [10:15<00:04, 17.1MB/s]
#  99%|█████████▉| 9.47G/9.54G [10:16<00:04, 17.7MB/s]
#  99%|█████████▉| 9.48G/9.54G [10:16<00:04, 18.0MB/s]
#  99%|█████████▉| 9.48G/9.54G [10:16<00:03, 17.3MB/s]
#  99%|█████████▉| 9.48G/9.54G [10:16<00:03, 17.2MB/s]
#  99%|█████████▉| 9.48G/9.54G [10:16<00:04, 15.1MB/s]
#  99%|█████████▉| 9.49G/9.54G [10:17<00:03, 16.3MB/s]
#  99%|█████████▉| 9.49G/9.54G [10:17<00:03, 17.1MB/s]
#  99%|█████████▉| 9.50G/9.54G [10:17<00:03, 16.2MB/s]
# 100%|█████████▉| 9.50G/9.54G [10:17<00:02, 16.6MB/s]
# 100%|█████████▉| 9.50G/9.54G [10:18<00:02, 15.9MB/s]
# 100%|█████████▉| 9.51G/9.54G [10:18<00:02, 16.4MB/s]
# 100%|█████████▉| 9.51G/9.54G [10:18<00:02, 16.8MB/s]
# 100%|█████████▉| 9.51G/9.54G [10:18<00:02, 16.0MB/s]
# 100%|█████████▉| 9.52G/9.54G [10:19<00:01, 16.5MB/s]
# 100%|█████████▉| 9.52G/9.54G [10:19<00:01, 16.8MB/s]
# 100%|█████████▉| 9.52G/9.54G [10:19<00:01, 16.1MB/s]
# 100%|█████████▉| 9.53G/9.54G [10:19<00:01, 16.5MB/s]
# 100%|█████████▉| 9.53G/9.54G [10:20<00:00, 16.8MB/s]
# 100%|█████████▉| 9.53G/9.54G [10:20<00:00, 16.1MB/s]
# 100%|█████████▉| 9.54G/9.54G [10:20<00:00, 16.5MB/s]
# 100%|██████████| 9.54G/9.54G [10:20<00:00, 16.5MB/s]
# Modell erfolgreich lokalisiert im Systemcache unter: /root/.cache/kagglehub/models/google/gemma-4/transformers/gemma-4-e2b-it/1

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

print("Initialisiere Inferenz-Pipeline (bfloat16 für VRAM-Effizienz)...")
try:
    processor = AutoTokenizer.from_pretrained(model_path)
    model = AutoModelForCausalLM.from_pretrained(
        model_path,
        device_map="auto",
        torch_dtype=torch.bfloat16
    )
    print("Lokaler Wächter online und inferenzbereit.")
except NameError:
    print("Modellpfad nicht gefunden. Führen Sie die obige Zelle zuerst aus.")
# Out:
# Initialisiere Inferenz-Pipeline (bfloat16 für VRAM-Effizienz)...
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights:   0%|          | 0/1951 [00:00<?, ?it/s]
# Lokaler Wächter online und inferenzbereit.

# %% [markdown]
# **Frage:** Warum ist diese Einsparung (Kompakte Parameter/bfloat16) ein entscheidender Faktor bei der Ausführung paralleler physikalischer Simulationen auf derselben Hardware?
#
# Die Reduzierung des Speicherbedarfs ist wichtig, weil hier nicht nur das KI-Modell läuft, sondern gleichzeitig auch eine physikalische Simulation auf derselben Hardware ausgeführt wird. Die Simulation braucht bereits Ressourcen wie RAM, CPU- und eventuell GPU-Leistung. Wenn das Modell zu groß ist, bleiben weniger Ressourcen für die eigentliche Simulation übrig.
#
# Durch die kompakte Modellgröße und die Nutzung von 	exttt{bfloat16} wird weniger Speicher benötigt. Dadurch kann das System stabiler laufen, es kommt seltener zu Speicherengpässen und die Reaktionszeit bleibt geringer. Das ist besonders wichtig bei Echtzeit- oder Near-Real-Time-Simulationen, weil dort Verzögerungen direkt die Regelung beeinflussen können.
#
# Außerdem unterstützt ein kleinerer Speicherbedarf die lokale Ausführung. Die Telemetriedaten müssen nicht an externe Cloud-Dienste geschickt werden, wodurch Latenz reduziert und die Datensouveränität besser geschützt wird.

# %% [markdown]
# ## Exercise 2: Aktivierung des Cognitive Core (Der Denkmodus)
#
# Dieser Prozess wird nativ gestartet, indem das Token `<|think|>` am Anfang der Systemnachricht platziert wird. Das Modell gibt seine logischen Gedankenschritte innerhalb der Trenner `<|channel>thought\n` und `<channel|>` aus.
#
# ### Instruktionen:
# 1. Implementieren Sie eine Inferenz-Funktion `generate_thoughtful_response`, die den System-Prompt so formatiert, dass der native Denkmodus aktiviert wird.
# 2. Nutzen Sie reguläre Ausdrücke (RegEx), um den Denkanal (`thought`) von der finalen Antwort zu trennen.
# 3. Schreiben Sie eine Hilfsfunktion, die die Gedankenblöcke aus der Historie entfernt, bevor die nächste Benutzerinteraktion stattfindet.

# %%
import re

def generate_thoughtful_response(system_prompt, user_message, max_new_tokens=512):
    messages = [
        {"role": "system", "content": f"<|think|>\n{system_prompt}"},
        {"role": "user", "content": user_message}
    ]

    prompt_text = processor.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    inputs = processor(text=prompt_text, return_tensors="pt").to(model.device)

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=False,
            eos_token_id=processor.eos_token_id
        )

    generated_tokens = outputs[0][inputs["input_ids"].shape[-1]:]
    decoded_output = processor.decode(generated_tokens, skip_special_tokens=False)

    thought_pattern = r"<\|channel>thought\s*(.*?)\s*<channel|>"
    thought_match = re.search(thought_pattern, decoded_output, re.DOTALL)

    # NEU (sicher):
    try:
        thought_content = thought_match.group(1).strip()
    except AttributeError:
        thought_content = "Kein expliziter Denkprozess aufgezeichnet."
        thought_match = None

    clean_response = re.sub(thought_pattern, "", decoded_output, flags=re.DOTALL).strip()
    clean_response = clean_response.replace("<turn|>", "").replace("<bos>", "").replace("<eos>", "").strip()

    return thought_content, clean_response

# %%
def clean_history(messages):
    """
    Hilfsfunktion: Entfernt Gedankenblöcke aus der Historie (State-Management).
    Dies verhindert eine kognitive Überladung und Token-Wachstum bei Multi-Turn Chats.
    """
    cleaned_messages = []
    thought_pattern = r"<\|channel>thought\s*.*?\s*<channel|>"
    for msg in messages:
        if msg["role"] == "model":
            clean_content = re.sub(thought_pattern, "", msg["content"], flags=re.DOTALL).strip()
            cleaned_messages.append({"role": "model", "content": clean_content})
        else:
            cleaned_messages.append(msg)
    return cleaned_messages

# %% [markdown]
# ## Exercise 3: Die diskrete Warteschlangensimulation (Foundry)
#
# Teile kommen an, warten im Puffer und werden von einer Maschine abgearbeitet. Wir simulieren dieses Verhalten stochastisch. Die Ankunftszeiten folgen einem Poisson-Prozess mit Rate $\lambda$ (Arrival Rate), die Bearbeitungszeiten an der Station folgen einer Exponential- bzw. Poisson-Verteilung mit Rate $\mu$ (Service Rate).
#
# ### Instruktionen:
# 1. Schreiben Sie eine Simulationsklasse `DiscreteFoundry`, die den Zustand eines Puffers abbildet.
# 2. Wenn die Ankunftsrate die Bearbeitungsrate übersteigt (Instabilität), füllt sich der Puffer.
# 3. Bei Erreichen der maximalen Kapazität kommt es zum Pufferüberlauf (Datenverlust/Ausschuss).
# 4. Die Methode `step()` muss die Systemvariablen aktualisieren und einen JSON-String exportieren.

# %%
import numpy as np
import json

class DiscreteFoundry:
    def __init__(self, arrival_rate=2.5, service_rate=1.0, capacity=15):
        self.arrival_rate = arrival_rate
        self.service_rate = service_rate
        self.capacity = capacity
        self.buffer = 0
        self.dropped = 0
        self.processed = 0

    def step(self):
        # Stochastische Approximation
        arrivals = np.random.poisson(self.arrival_rate)
        services = np.random.poisson(self.service_rate)

        self.buffer += arrivals

        # Überlauf prüfen
        if self.buffer > self.capacity:
            overflow = self.buffer - self.capacity
            self.dropped += overflow
            self.buffer = self.capacity

        # Verarbeitung
        processed_now = min(self.buffer, services)
        self.buffer -= processed_now
        self.processed += processed_now

        return {
            "queue_length": self.buffer,
            "max_capacity": self.capacity,
            "dropped_parts": self.dropped,
            "processed_parts": self.processed,
            "current_service_rate": self.service_rate
        }

# %%
# Instanziierung der Produktionslinie
production_line = DiscreteFoundry()
print("Initialer Tick:", json.dumps(production_line.step()))
# Out:
# Initialer Tick: {"queue_length": 1, "max_capacity": 15, "dropped_parts": 0, "processed_parts": 0, "current_service_rate": 1.0}

# %% [markdown]
# ## Exercise 4: Geschlossener Regelkreis mit kognitiver Instanz
#
# Die Telemetriedaten werden an den lokalen Wächter übergeben. Dieser analysiert die Situation offline im Denkanal, trifft eine kognitive Entscheidung und gibt einen neuen Wert für die Service-Rate vor, welcher unmittelbar in die Simulation zurückgeführt wird.
#
# ### Instruktionen:
# 1. Konzipieren Sie einen System-Prompt für Gemma 4, der das Modell anweist, als industrieller Regler zu agieren.
# 2. Das Modell muss den Systemzustand bewerten und die Service-Rate anpassen (Intervall: $[0.5, 3.0]$).
# 3. Enforcieren Sie ein klares Ausgabe-Format, um den neuen Parameter numerisch parsen zu können.
# 4. Lassen Sie die gesteuerte Simulation über 8 Zeitschritte laufen.

# %%
sentinel_system_prompt = """
Du bist der souveräne Wächter (KI-Regler) einer industriellen Fabrikationsstraße.
Dein Ziel ist es, Pufferüberläufe (dropped_parts) zu minimieren, aber gleichzeitig Energie zu sparen.
Maximales Intervall für Service-Rate: 0.5 bis 3.0.
Analysiere die Telemetrie: Wenn queue_length hoch ist, erhöhe die Rate drastisch. Wenn niedrig, senke sie.
Gib AUSSCHLIESSLICH den neuen Wert in der letzten Zeile im exakten Format aus:
NEW_SERVICE_RATE: <wert>
"""

print("=== START DES GESCHLOSSENEN REGELKREISES ===")
try:
    for tick in range(8):
        # 1. Systemschritt
        telemetry_data = production_line.step()
        print(f"\n[Tick {tick+1}] Telemetrie-Eingang: {json.dumps(telemetry_data)}")

        # 2. Prompt-Generierung
        user_query = f"Statusbericht: {json.dumps(telemetry_data)}\nAktuell eingestellte Service-Rate: {production_line.service_rate}. Entscheidung?"

        # 3. Lokale Inferenz
        thought_process, action_response = generate_thoughtful_response(sentinel_system_prompt, user_query, max_new_tokens=256)

        print(f"💭 [Denkanal]: {thought_process[:200]}... [gekürzt]")
        print(f"🤖 [Modell-Entscheidung]: {action_response}")

        # 4. Parsing der Entscheidung
        match = re.search(r"NEW_SERVICE_RATE:\s*([0-9.]+)", action_response)
        if match:
            proposed_rate = float(match.group(1))
            # Physikalische Absicherung über System-Schranken
            validated_rate = max(0.5, min(3.0, proposed_rate))
            production_line.service_rate = validated_rate
            print(f">>> System-Aktion: Service-Rate für Schritt {tick+2} auf {validated_rate} aktualisiert.")
        else:
            print("!!! Parsing-Fehler: Keine gültige Anpassung gefunden. Behalte aktuellen Parameter bei.")
except NameError:
    print("Das Modell wurde in Zelle 4 noch nicht erfolgreich in den Speicher geladen.")
# Out:
# === START DES GESCHLOSSENEN REGELKREISES ===
#
# [Tick 1] Telemetrie-Eingang: {"queue_length": 1, "max_capacity": 15, "dropped_parts": 0, "processed_parts": 3, "current_service_rate": 1.0}
# 💭 [Denkanal]: Kein expliziter Denkprozess aufgezeichnet.... [gekürzt]
# 🤖 [Modell-Entscheidung]: <|channelthought
# Thinking Process:
#
# 1.  **Analyze the Request & Role:**
#     *   **Role:** Sovereign Guardian (AI Controller) of an industrial manufacturing line.
#     *   **Goal:** Minimize dropped parts (`dropped_parts`) AND save energy.
#     *   **Constraint 1 (Service Rate):** Maximum interval for Service Rate is 0.5 to 3.0.
#     *   **Constraint 2 (Telemetry Logic):**
#         *   If `queue_length` is high - Increase rate drastically.
#         *   If `queue_length` is low - Decrease rate.
#     *   **Output Format:** ONLY `NEW_SERVICE_RATE: <value` in the last line.
#
# 2.  **Analyze the Telemetry Data:**
#     *   `queue_length`: 1
#     *   `max_capacity`: 15
#     *   `dropped_parts`: 0
#     *   `processed_parts`: 3
#     *   `current_service_rate`: 1.0
#
# 3.  **Evaluate the State:**
#     *   The queue length is 1. This is very low compared to the max capacity of
# !!! Parsing-Fehler: Keine gültige Anpassung gefunden. Behalte aktuellen Parameter bei.
#
# [Tick 2] Telemetrie-Eingang: {"queue_length": 7, "max_capacity": 15, "dropped_parts": 0, "processed_parts": 3, "current_service_rate": 1.0}
# 💭 [Denkanal]: Kein expliziter Denkprozess aufgezeichnet.... [gekürzt]
# 🤖 [Modell-Entscheidung]: <|channelthought
# Thinking Process:
#
# 1.  **Analyze the Request & Role:**
#     *   **Role:** Sovereign Guardian (AI Controller) of an industrial manufacturing line.
#     *   **Goal:** Minimize dropped parts (`dropped_parts`) AND save energy.
#     *   **Constraint 1 (Service Rate):** Maximum interval for Service Rate is 0.5 to 3.0.
#     *   **Constraint 2 (Telemetry Logic):**
#         *   If `queue_length` is high - Increase rate drastically.
#         *   If `queue_length` is low - Decrease rate.
#     *   **Output Format:** ONLY `NEW_SERVICE_RATE: <value` in the last line.
#
# 2.  **Analyze the Telemetry Data:**
#     *   `queue_length`: 7
#     *   `max_capacity`: 15
#     *   `dropped_parts`: 0 (Good)
#     *   `processed_parts`: 3
#     *   `current_service_rate`: 1.0
#
# 3.  **Evaluate the Queue Length:**
#     *   The queue length is 7 out of a max capacity of 1
# !!! Parsing-Fehler: Keine gültige Anpassung gefunden. Behalte aktuellen Parameter bei.
#
# [Tick 3] Telemetrie-Eingang: {"queue_length": 10, "max_capacity": 15, "dropped_parts": 0, "processed_parts": 4, "current_service_rate": 1.0}
# 💭 [Denkanal]: Kein expliziter Denkprozess aufgezeichnet.... [gekürzt]
# 🤖 [Modell-Entscheidung]: <|channelthought
# Thinking Process:
#
# 1.  **Analyze the Goal:** Minimize dropped parts (`dropped_parts`) while saving energy.
# 2.  **Analyze Constraints:**
#     *   Max Service Rate interval: 0.5 to 3.0.
#     *   Action based on telemetry:
#         *   High `queue_length` - Increase rate drastically.
#         *   Low `queue_length` - Decrease rate.
# 3.  **Analyze the Telemetry:**
#     *   `queue_length`: 10
#     *   `max_capacity`: 15
#     *   `dropped_parts`: 0 (Good)
#     *   `processed_parts`: 4
#     *   `current_service_rate`: 1.0
# 4.  **Evaluate Queue Status:**
#     *   The queue length is 10 out of a max capacity of 15. This is moderately high (66.7% utilization).
# 5.  **Determine Action:** Since the queue length (10) is significant, the system needs to increase the service rate to prevent future buildup and potential drops, even though current drops are zero.
# 6.  **Select
# !!! Parsing-Fehler: Keine gültige Anpassung gefunden. Behalte aktuellen Parameter bei.
#
# [Tick 4] Telemetrie-Eingang: {"queue_length": 13, "max_capacity": 15, "dropped_parts": 0, "processed_parts": 4, "current_service_rate": 1.0}
# 💭 [Denkanal]: Kein expliziter Denkprozess aufgezeichnet.... [gekürzt]
# 🤖 [Modell-Entscheidung]: <|channelthought
# Thinking Process:
#
# 1.  **Analyze the Request & Role:**
#     *   **Role:** Sovereign Guardian (AI Controller) of an industrial manufacturing line.
#     *   **Goal:** Minimize dropped parts (`dropped_parts`) AND save energy.
#     *   **Constraint 1 (Service Rate):** Maximum interval for Service Rate is 0.5 to 3.0.
#     *   **Constraint 2 (Decision Logic):**
#         *   If `queue_length` is high - Increase rate drastically.
#         *   If `queue_length` is low - Decrease rate.
#     *   **Output Format:** ONLY `NEW_SERVICE_RATE: <value` in the last line.
#
# 2.  **Analyze the Telemetry Data:**
#     *   `queue_length`: 13
#     *   `max_capacity`: 15
#     *   `dropped_parts`: 0
#     *   `processed_parts`: 4
#     *   `current_service_rate`: 1.0
#
# 3.  **Evaluate the State:**
#     *   The queue length is 13 out of 15 capacity. This is high
# !!! Parsing-Fehler: Keine gültige Anpassung gefunden. Behalte aktuellen Parameter bei.
#
# [Tick 5] Telemetrie-Eingang: {"queue_length": 15, "max_capacity": 15, "dropped_parts": 2, "processed_parts": 4, "current_service_rate": 1.0}
# 💭 [Denkanal]: Kein expliziter Denkprozess aufgezeichnet.... [gekürzt]
# 🤖 [Modell-Entscheidung]: <|channelthought
# Thinking Process:
#
# 1.  **Analyze the Goal:** Minimize dropped parts (`dropped_parts`) while saving energy.
# 2.  **Analyze Constraints:**
#     *   Max Service Rate interval: 0.5 to 3.0.
#     *   Action based on telemetry:
#         *   High `queue_length` - Increase rate drastically.
#         *   Low `queue_length` - Decrease rate.
# 3.  **Analyze the Telemetry:**
#     *   `queue_length`: 15
#     *   `max_capacity`: 15
#     *   `dropped_parts`: 2 (This is the current problem indicator)
#     *   `processed_parts`: 4
#     *   `current_service_rate`: 1.0
# 4.  **Evaluate Queue Status:**
#     *   The queue length (15) is at maximum capacity (15). This indicates a severe bottleneck or that the current service rate (1.0) is insufficient to keep up with the input rate.
# 5.  **Determine Action:** Since the queue is full and parts are being dropped (2 dropped parts), the service rate must be increased drastically to
# !!! Parsing-Fehler: Keine gültige Anpassung gefunden. Behalte aktuellen Parameter bei.
#
# [Tick 6] Telemetrie-Eingang: {"queue_length": 13, "max_capacity": 15, "dropped_parts": 3, "processed_parts": 6, "current_service_rate": 1.0}
# 💭 [Denkanal]: Kein expliziter Denkprozess aufgezeichnet.... [gekürzt]
# 🤖 [Modell-Entscheidung]: <|channelthought
# Thinking Process:
#
# 1.  **Analyze the Goal:** Minimize dropped parts (`dropped_parts`) while saving energy.
# 2.  **Analyze Constraints:**
#     *   Max Service Rate interval: 0.5 to 3.0.
#     *   Action based on telemetry:
#         *   High `queue_length` - Increase rate drastically.
#         *   Low `queue_length` - Decrease rate.
# 3.  **Analyze the Telemetry:**
#     *   `queue_length`: 13
#     *   `max_capacity`: 15
#     *   `dropped_parts`: 3 (This is the metric to minimize)
#     *   `processed_parts`: 6
#     *   `current_service_rate`: 1.0
# 4.  **Evaluate Queue Status:**
#     *   The queue length (13) is high relative to the max capacity (15). The system is nearing saturation.
# 5.  **Determine Action:** Since the queue length is high, the service rate must be increased drastically to prevent further drops.
# 6.  **Select New Rate:** The current rate is 1.0. I need to
# !!! Parsing-Fehler: Keine gültige Anpassung gefunden. Behalte aktuellen Parameter bei.
#
# [Tick 7] Telemetrie-Eingang: {"queue_length": 15, "max_capacity": 15, "dropped_parts": 4, "processed_parts": 6, "current_service_rate": 1.0}
# 💭 [Denkanal]: Kein expliziter Denkprozess aufgezeichnet.... [gekürzt]
# 🤖 [Modell-Entscheidung]: <|channelthought
# Thinking Process:
#
# 1.  **Analyze the Goal:** Minimize dropped parts (`dropped_parts`) while saving energy.
# 2.  **Analyze Constraints:**
#     *   Max Service Rate interval: 0.5 to 3.0.
#     *   Action based on telemetry:
#         *   High `queue_length` - Increase rate drastically.
#         *   Low `queue_length` - Decrease rate.
# 3.  **Analyze the Telemetry:**
#     *   `queue_length`: 15
#     *   `max_capacity`: 15
#     *   `dropped_parts`: 4 (This is the current problem indicator)
#     *   `processed_parts`: 6
#     *   `current_service_rate`: 1.0
# 4.  **Evaluate Queue Status:** The queue length (15) is at maximum capacity (15). This indicates a severe bottleneck and high risk of further drops.
# 5.  **Determine Action:** Since the queue is full and parts are being dropped, the service rate must be increased drastically to clear the backlog.
# 6.  **Select New Rate:** The current rate is 1.0.
# !!! Parsing-Fehler: Keine gültige Anpassung gefunden. Behalte aktuellen Parameter bei.
#
# [Tick 8] Telemetrie-Eingang: {"queue_length": 14, "max_capacity": 15, "dropped_parts": 7, "processed_parts": 7, "current_service_rate": 1.0}
# 💭 [Denkanal]: Kein expliziter Denkprozess aufgezeichnet.... [gekürzt]
# 🤖 [Modell-Entscheidung]: <|channelthought
# Thinking Process:
#
# 1.  **Analyze the Goal:** Minimize dropped parts (`dropped_parts`) while saving energy.
# 2.  **Analyze Constraints:**
#     *   Maximum Service Rate interval: 0.5 to 3.0.
#     *   Action based on telemetry:
#         *   If `queue_length` is high - Increase rate drastically.
#         *   If `queue_length` is low - Decrease rate.
# 3.  **Analyze the Telemetry:**
#     *   `queue_length`: 14
#     *   `max_capacity`: 15
#     *   `dropped_parts`: 7 (This is high, 7/14 parts dropped, indicating a bottleneck or insufficient processing speed relative to input/demand).
#     *   `processed_parts`: 7
#     *   `current_service_rate`: 1.0
# 4.  **Evaluate Queue Length:** The queue length is 14 out of a max capacity of 15. This is very high (93% utilization/near saturation).
# 5.  **Determine Action:** Since the queue length is high, the service rate must be increased drastically to prevent
# !!! Parsing-Fehler: Keine gültige Anpassung gefunden. Behalte aktuellen Parameter bei.

# %% [markdown]
# ## Exercise 5: Cloud-gestütztes Fine-Tuning über die Colab CLI
#
# Um das daten- und rechenintensive Modell-Training auszulagern, ohne den lokalen Terminal-Workflow zu unterbrechen, nutzen wir die neue **Google Colab CLI** (`google-colab-cli`). Sie ermöglicht es uns, über ein einziges Kommando Remote-GPUs im Google-Rechenzentrum zu provisionieren, Skripte auszuführen und Trainings-Ergebnisse (LoRA-Adapter) direkt in unseren lokalen Workspace herunterzuladen.
#
# ### Szenario:
# Wir wollen ein feingetuntes **Gemma 4 E2B**-Modell über QLoRA trainieren, damit es Telemetrieberichte direkt in formstabilen industriellen Steuerungscodes formatiert.
#
# ### Instruktionen:
# 1. Installieren Sie die offizielle Google Colab CLI in Ihrer Terminal-Umgebung.
# 2. Erstellen Sie ein lokales Python-Skript `finetune_run.py`, das Gemma 4 unter Verwendung von KerasNLP/Transformers für ein LoRA-Feintuning initialisiert.
# 3. Verwenden Sie die Colab CLI-Befehlssequenz, um ein Remote-System mit einer T4 GPU anzufordern, die Pakete zu installieren, das Skript auszuführen und die fertig trainierten Gewichts-Adapter (`safetensors`) zurück in Ihren lokalen Ordner zu übertragen.

# %%
# Optionale Installation der CLI im lokalen Terminal:
# pip install google-colab-cli

# %%
finetune_script = """
import keras
import keras_hub
import os

os.environ["KERAS_BACKEND"] = "jax"

print("Lade Gemma 4 E2B für LoRA Fine-Tuning...")
gemma_lm = keras_hub.models.GemmaCausalLM.from_preset("gemma_2b_en")

# 2. Aktivierung von Low-Rank Adaptation (LoRA)
gemma_lm.backbone.enable_lora(rank=4)

# 3. Dummy-Trainingsdaten formatieren
training_data = [
    {"prompt": "Status: queue_length=14. Action?", "response": "NEW_SERVICE_RATE: 3.0"},
    {"prompt": "Status: queue_length=1. Action?", "response": "NEW_SERVICE_RATE: 0.5"}
]
prompts = [f"{item['prompt']} -> {item['response']}" for item in training_data]

# 4. Kompilierung des Modells mit optimierter Lernrate
gemma_lm.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=keras.optimizers.Adam(learning_rate=2e-4),
    weighted_metrics=["accuracy"]
)

# 5. Training für eine repräsentative Epoche
gemma_lm.fit(prompts, epochs=1, batch_size=2)

# 6. Sichern des trainierten Adapters im VM-Speicher
gemma_lm.save_to_preset("./gemma4_lora_adapter")
print("Feintuning erfolgreich abgeschlossen. Gewichte lokal in der Colab-VM gespeichert.")
"""

with open("finetune_run.py", "w") as f:
    f.write(finetune_script.strip())
print("Lokales Skript 'finetune_run.py' erstellt und bereit zum Versand!")
# Out:
# Lokales Skript 'finetune_run.py' erstellt und bereit zum Versand!

# %% [markdown]
# Das folgende Kommando veranschaulicht den transparenten Code-Uplink in der Bash-Shell:
#
# ```bash
# # 1. Allokieren Sie eine neue Remote-VM mit einer performanten T4-GPU
# colab new -s gemma-tuning --gpu T4
#
# # 2. Installieren Sie die modernsten ML-Bibliotheken direkt auf der Remote-Instanz via 'uv'
# colab install -s gemma-tuning keras-hub keras tensorflow torch
#
# # 3. Führen Sie Ihr lokales Python-Skript direkt auf der remote GPU aus (Transparenter Code-Uplink)
# colab exec -s gemma-tuning -f finetune_run.py
#
# # 4. Laden Sie das Ergebnis (den fertigen LoRA-Gewichts-Adapter) sicher herunter
# colab download -s gemma-tuning /content/gemma4_lora_adapter ./local_gemma4_adapter
#
# # 5. Beenden Sie die Remote-Sitzung, um Ihre Rechenressourcen zu schonen
# colab stop -s gemma-tuning
# ```

# %% [markdown]
# **Frage:** Wie schützt das Zusammenspiel aus Colab CLI und lokalem Edge-Modell die geistige Souveränität Ihrer Simulationsdaten?
#
# Das Zusammenspiel aus Colab CLI und lokalem Edge-Modell schützt die geistige Souveränität der Simulationsdaten, weil die sensiblen Produktions- und Telemetriedaten weiterhin lokal verarbeitet werden können. Das lokale Edge-Modell übernimmt die Analyse und Regelung direkt in der eigenen Umgebung, ohne dass laufende Simulationsdaten dauerhaft in eine externe Cloud übertragen werden müssen.
#
# Die Colab CLI wird nur für rechenintensive Trainingsschritte genutzt, zum Beispiel um LoRA-Adapter auf einer entfernten GPU zu trainieren. Dadurch wird die starke Rechenleistung der Cloud verwendet, während die eigentliche Simulation und die operative Entscheidungslogik lokal bleiben. Nach dem Training können die erzeugten Adapter wieder heruntergeladen und offline im lokalen System eingesetzt werden.
#
# Damit entsteht eine sinnvolle Trennung: Die Cloud hilft bei der Berechnung, aber die Kontrolle über Modell, Datenfluss und spätere Nutzung bleibt beim lokalen System. So werden Abhängigkeit, Latenz und ungewollte Datenweitergabe reduziert.

# %% [markdown]
# ## Exercise 6: Kontext-Injektion (Lokales RAG für SOPs)
#
# Der Wächter muss spezifische Maschinenvorgaben (Standard Operating Procedures, SOPs) heranziehen, um den optimalen Modus auszuwählen. In dieser Übung implementieren Sie ein offline-fähiges RAG-System, das auf Basis der aktuellen Queue-Länge die passende Regelungsvorschrift aus einem lokalen Dokumentenindex extrahiert und als Kontext in das Gemma 4-Modell einspeist.
#
# ### Instruktionen:
# 1. Erstellen Sie eine Liste von SOPs als lokalen Text-Index.
# 2. Implementieren Sie eine einfache, abstandsbasierte Suchfunktion (z. B. Keyword-Matching oder Cosine-Similarity über Wortfrequenzen), um das relevanteste SOP-Dokument basierend auf der Queue-Länge zu filtern.
# 3. Integrieren Sie dieses Dokument als zusätzlichen Kontext in den Prompt für Gemma 4.

# %%
# Lokaler RAG-Index
SOP_DATABASE = {
    "SOP-101_NORMAL": "Warteschlange < 5. Maschine im Eco-Modus belassen. Rate auf 1.0 drosseln.",
    "SOP-202_WARNING": "Warteschlange >= 5 und <= 10. Maschine in Normalbetrieb. Rate auf 2.0 erhöhen.",
    "SOP-999_CRITICAL": "Warteschlange > 10. NOTFALL-PROTOKOLL. Rate zwingend auf 3.0 setzen!"
}

def retrieve_relevant_sop(queue_length):
    if queue_length > 10:
        return SOP_DATABASE["SOP-999_CRITICAL"]
    elif queue_length >= 5:
        return SOP_DATABASE["SOP-202_WARNING"]
    else:
        return SOP_DATABASE["SOP-101_NORMAL"]

# Testlauf des lokalen RAG-Systems
test_queue = 12
retrieved_sop = retrieve_relevant_sop(test_queue)
print(f"Extrahierte SOP für Warteschlangenlänge {test_queue}:\n-> {retrieved_sop}")
# Out:
# Extrahierte SOP für Warteschlangenlänge 12:
# -> Warteschlange > 10. NOTFALL-PROTOKOLL. Rate zwingend auf 3.0 setzen!

# %%
# Demonstration der RAG-gestützten Prompt-Injektion
augmented_prompt = f"{sentinel_system_prompt}\n\nWICHTIGE VORSCHRIFT (SOP) FÜR DIESEN SCHRITT:\n{retrieved_sop}"
demo_query = f"Statusbericht: Queue={test_queue}, Capacity=15. Aktuelle Service-Rate: 1.0. Entscheidung?"

try:
    t, a = generate_thoughtful_response(augmented_prompt, demo_query, max_new_tokens=256)
    print("\n=== RAG-AUGMENTIERTE ENTSCHEIDUNG ===")
    print("Gedanken:\n", t)
    print("\nAktion:\n", a)
except NameError:
    print("Bitte stellen Sie sicher, dass das Gemma-Modell in Zelle 4 geladen wurde.")
# Out:
# === RAG-AUGMENTIERTE ENTSCHEIDUNG ===
# Gedanken:
#  Kein expliziter Denkprozess aufgezeichnet.
#
# Aktion:
#  <|channelthought
# Thinking Process:
#
# 1.  **Analyze the Request & Role:** I am the Sovereign Guardian (AI Controller) of an industrial production line.
#     *   **Goal:** Minimize dropped parts (`dropped_parts`) AND save energy.
#     *   **Constraint 1 (Service Rate):** Max interval for Service Rate is 0.5 to 3.0.
#     *   **Constraint 2 (Telemetry Rule):**
#         *   If `queue_length` is high - Increase rate drastically.
#         *   If `queue_length` is low - Decrease rate.
#     *   **Constraint 3 (SOP - Emergency Protocol):** If `queue_length`  10, set rate to 3.0.
#     *   **Output Format:** ONLY `NEW_SERVICE_RATE: <value`
#
# 2.  **Analyze the Input Telemetry:**
#     *   `Queue = 12`
#     *   `Capacity = 15`
#     *   `Current Service Rate = 1.0`
#
# 3.  **Apply Decision Logic:**
#     *   **Check SOP:** Is Queue (12)  10? Yes

# %% [markdown]
# **Frage zur Reflexion:**
# Inwiefern erleichtert dieser Ansatz die Anpassung der Systemlogik, wenn sich die Werksvorschriften ändern?
# Dieser Ansatz erleichtert die Anpassung der Systemlogik, weil die Regeln nicht fest im Modell oder tief im Programmcode versteckt sind, sondern als lokale SOP-Dokumente im RAG-Index liegen. Wenn sich Werksvorschriften ändern, muss man nicht das ganze Modell neu trainieren oder die komplette Regelungslogik neu schreiben.
#
# Stattdessen kann einfach der passende SOP-Eintrag im lokalen Index geändert, ergänzt oder ersetzt werden. Der Wächter bekommt dann beim nächsten Schritt automatisch den aktuellen Kontext in den Prompt eingefügt und entscheidet auf Basis der neuen Vorschrift.
#
# Das macht das System flexibler, nachvollziehbarer und besser wartbar. Besonders in einer Fabrik ist das wichtig, weil Sicherheitsregeln, Grenzwerte oder Prozessvorgaben regelmäßig angepasst werden können.
